# %% [markdown]
# # 8장. 텍스트빈도분석 - 1.영어단어분석

# %% [markdown]
# ### 영어 단어 분석에 필요한 패키지 준비

# %%
#최초 한번만 설치:Anaconda에 설치됨
# ! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\seokilsong\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in c:\users\seokilsong\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)

# %%
#최초 한번만 설치:Anaconda에 설치됨
# ! pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: pillow in c:\users\seokilsong\anaconda3\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in c:\users\seokilsong\anaconda3\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\seokilsong\anaconda3\lib\site-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\seokilsong\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six in c:\users\seokilsong\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\seokilsong\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\seokilsong\anaconda3\lib\site-packages)

# %%
import pandas as pd
import glob
import re
from functools import reduce

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from collections import Counter

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ### 기본적으로 아나콘다에 nltk 가 설치되어있음
# ### nltk의 리소스는 별도 다운로드 필요

# %%
import nltk     # nltk.download() 를 하기위해, import 함.

# %%
# nltk.download()  # 최초 한번만 설치: download 창이 뜨면, 모두 선택하고 [Download] 버튼 클릭!
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# # 1. 데이터 준비

# %% [markdown]
# ### 1-1. 파일 병합
# - 총 10개의 파일을 하나의 파일로 병합

# %%
all_files = glob.glob('data/myCabinetExcelData*.xls')

all_files #출력하여 내용 확인
# Out:
# ['data\\myCabinetExcelData (1).xls',
#  'data\\myCabinetExcelData (2).xls',
#  'data\\myCabinetExcelData (3).xls',
#  'data\\myCabinetExcelData (4).xls',
#  'data\\myCabinetExcelData (5).xls',
#  'data\\myCabinetExcelData (6).xls',
#  'data\\myCabinetExcelData (7).xls',
#  'data\\myCabinetExcelData (8).xls',
#  'data\\myCabinetExcelData (9).xls',
#  'data\\myCabinetExcelData.xls']

# %%
all_files_data = [] #저장할 리스트 

for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)

all_files_data[0] #출력하여 내용 확인
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Guest Editorial: Big Media Data: Understanding...
# 1          NaN    2  Guest Editorial: Big Scholar Data Discovery an...
# 2          NaN    3    Guest Editorial: Big Data Analytics and the Web
# 3          NaN    4  Parallel computing for preserving privacy usin...
# 4          NaN    5                       NoSQL databases for big data
# ..         ...  ...                                                ...
# 95         NaN   96  Smart city big data analytics: An advanced review
# 96         NaN   97  A watchdog approach - name-matching algorithm ...
# 97         NaN   98  An intelligent approach to Big Data analytics ...
# 98         NaN   99  How organisations leverage Big Data: a maturit...
# 99         NaN  100  Effective and efficient distributed management...
#
#                                                    저자  \
# 0         Wang, J.; Qi, G.; Sebe, N.; Aggarwal, C. C.
# 1          Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.
# 2        Sheng, M.; Vasilakos, A. V.; Yu, Q.; You, L.
# 3                          Yaji, Sharath; Neelima, B.
# 4   Oussous, Ahmed; Benjelloun, Fatima-Zahra; Lahc...
# ..                                                ...
# 95  Soomro, Kamran; Bhutta, Muhammad Nasir Mumtaz;...
# 96                Kirubakaran, Anusuya; Aramudhan, M.
# 97                       Verma, Neha; Singh, Jatinder
# 98                        Comuzzi, Marco; Patel, Anit
# 99  Cuzzocrea, Alfredo; Grasso, Giorgio Mario; Nol...
#
#                                  출판사   출판일
# 0                            unknown  2015
# 1                            unknown  2016
# 2                            unknown  2016
# 3                       Inderscience  2018
# 4                       Inderscience  2017
# ..                               ...   ...
# 95             John Wiley & Sons Ltd  2019
# 96                      Inderscience  2018
# 97  Emerald Group Publishing Limited  2017
# 98  Emerald Group Publishing Limited  2016
# 99                      Inderscience  2019
#
# [100 rows x 6 columns]

# %%
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)

all_files_data_concat #출력하여 내용 확인
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  Guest Editorial: Big Media Data: Understanding...
# 1           NaN    2  Guest Editorial: Big Scholar Data Discovery an...
# 2           NaN    3    Guest Editorial: Big Data Analytics and the Web
# 3           NaN    4  Parallel computing for preserving privacy usin...
# 4           NaN    5                       NoSQL databases for big data
# ..          ...  ...                                                ...
# 995         NaN   96  Guest Editorial: Big Media Data: Understanding...
# 996         NaN   97  Guest Editorial: Big Scholar Data Discovery an...
# 997         NaN   98  Guest Editorial: Big Media Data: Understanding...
# 998         NaN   99  Speed Up Big Data Analytics by Unveiling the S...
# 999         NaN  100        Architecting Time-Critical Big-Data Systems
#
#                                                     저자           출판사   출판일
# 0          Wang, J.; Qi, G.; Sebe, N.; Aggarwal, C. C.       unknown  2015
# 1           Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.       unknown  2016
# 2         Sheng, M.; Vasilakos, A. V.; Yu, Q.; You, L.       unknown  2016
# 3                           Yaji, Sharath; Neelima, B.  Inderscience  2018
# 4    Oussous, Ahmed; Benjelloun, Fatima-Zahra; Lahc...  Inderscience  2017
# ..                                                 ...           ...   ...
# 995           Wang, J.; Qi, G.; Sebe, N.; Aggarwal, C.       unknown  2017
# 996         Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.       unknown  2017
# 997        Wang, J.; Qi, G.; Sebe, N.; Aggarwal, C. C.       unknown  2016
# 998  Wang, J.; Zhang, X.; Yin, J.; Wang, R.; Wu, H....       unknown  2018
# 999  Basanta-Val, P.; Audsley, N. C.; Wellings, A. ...       unknown  2016
#
# [1000 rows x 6 columns]

# %%
all_files_data_concat.to_csv('data/riss_bigdata.csv', encoding='utf-8', index = False)

# %% [markdown]
# ### 1-2. 데이터 전처리 (Pre-processing)
# #### 1. 정제
# #### 1. 정규화
# #### 1. 토큰화
# #### 2. 불용어 제거
# #### 3. 표제어 추출

# %%
# 제목 추출
all_title = all_files_data_concat['제목']

all_title #출력하여 내용 확인
# Out:
# 0      Guest Editorial: Big Media Data: Understanding...
# 1      Guest Editorial: Big Scholar Data Discovery an...
# 2        Guest Editorial: Big Data Analytics and the Web
# 3      Parallel computing for preserving privacy usin...
# 4                           NoSQL databases for big data
#                              ...
# 995    Guest Editorial: Big Media Data: Understanding...
# 996    Guest Editorial: Big Scholar Data Discovery an...
# 997    Guest Editorial: Big Media Data: Understanding...
# 998    Speed Up Big Data Analytics by Unveiling the S...
# 999          Architecting Time-Critical Big-Data Systems
# Name: 제목, Length: 1000, dtype: object

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()

# %%
words = []  

for title in all_title:
    # 정제 과정 (알파벳으로 시삭하지 않는 단어 제거)
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title))
    # 정규화 및 토큰화 (토큰 분리 및 소문자 변환)    
    EnWordsToken = word_tokenize(EnWords.lower())
    # 불용어 제거    
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords]
    # 표제어 추출
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop]
    words.append(EnWordsTokenStopLemma)

# %%
words  #출력하여 내용 확인
# Out:
# [['guest',
#   'editorial',
#   'big',
#   'medium',
#   'data',
#   'understanding',
#   'search',
#   'mining',
#   'part'],
#  ['guest',
#   'editorial',
#   'big',
#   'scholar',
#   'data',
#   'discovery',
#   'collaboration'],
#  ['guest', 'editorial', 'big', 'data', 'analytics', 'web'],
#  ['parallel',
#   'computing',
#   'preserving',
#   'privacy',
#   'using',
#   'k',
#   'anonymisation',
#   'algorithm',
#   'big',
#   'data'],
#  ['nosql', 'database', 'big', 'data'],
#  ['computation',
#   'migration',
#   'new',
#   'approach',
#   'execute',
#   'big',
#   'data',
#   'bioinformatics',
#   'workflow'],
#  ['towards',
#   'real',
#   'time',
#   'big',
#   'data',
#   'analytics',
#   'platform',
#   'health',
#   'application'],
#  ['new',
#   'approach',
#   'accurate',
#   'distributed',
#   'cluster',
#   'analysis',
#   'big',
#   'data',
#   'competitive',
#   'k',
#   'mean'],
#  ['five', 'layer', 'architecture', 'big', 'data', 'processing', 'analytics'],
#  ['towards',
#   'max',
#   'min',
#   'fair',
#   'resource',
#   'allocation',
#   'stream',
#   'big',
#   'data',
#   'analytics',
#   'shared',
#   'cloud'],
#  ['large',
#   'scale',
#   'spectral',
#   'clustering',
#   'managing',
#   'big',
#   'data',
#   'healthcare',
#   'operation'],
#  ['hierarchical',
#   'distributed',
#   'processing',
#   'framework',
#   'big',
#   'image',
#   'data'],
#  ['platform',
#   'big',
#   'data',
#   'analytics',
#   'distributed',
#   'scale',
#   'storage',
#   'system'],
#  ['online', 'similarity', 'learning', 'big', 'data', 'overfitting'],
#  ['towards',
#   'quality',
#   'service',
#   'driven',
#   'consistency',
#   'big',
#   'data',
#   'management'],
#  ['platform',
#   'big',
#   'data',
#   'analytics',
#   'distributed',
#   'scale',
#   'storage',
#   'system'],
#  ['current', 'trend', 'predictive', 'analytics', 'big', 'data'],
#  ['classification', 'comparison', 'nosql', 'big', 'data', 'model'],
#  ['survey',
#   'big',
#   'data',
#   'processing',
#   'infrastructure',
#   'evolving',
#   'role',
#   'fpga'],
#  ['fast',
#   'approach',
#   'semantic',
#   'service',
#   'composition',
#   'big',
#   'data',
#   'environment'],
#  ['secure',
#   'multi',
#   'owner',
#   'based',
#   'cloud',
#   'computing',
#   'scheme',
#   'big',
#   'data'],
#  ['corporate',
#   'governance',
#   'fraud',
#   'detection',
#   'annual',
#   'report',
#   'using',
#   'big',
#   'data',
#   'analytics'],
#  ['fuzzy',
#   'based',
#   'scalable',
#   'clustering',
#   'algorithm',
#   'handling',
#   'big',
#   'data',
#   'using',
#   'apache',
#   'spark'],
#  ['privacy', 'model', 'big', 'data', 'survey'],
#  ['towards',
#   'quality',
#   'service',
#   'driven',
#   'consistency',
#   'big',
#   'data',
#   'management'],
#  ['new',
#   'approach',
#   'accurate',
#   'distributed',
#   'cluster',
#   'analysis',
#   'big',
#   'data',
#   'competitive',
#   'k',
#   'mean'],
#  ['palopro',
#   'platform',
#   'knowledge',
#   'extraction',
#   'big',
#   'social',
#   'data',
#   'news'],
#  ['index', 'ieee', 'transaction', 'big', 'data', 'vol'],
#  ['hybridisation', 'classifier', 'anomaly', 'detection', 'big', 'data'],
#  ['toward',
#   'efficient',
#   'flexible',
#   'metadata',
#   'indexing',
#   'big',
#   'data',
#   'system'],
#  ['structural',
#   'balance',
#   'theory',
#   'based',
#   'e',
#   'commerce',
#   'recommendation',
#   'big',
#   'rating',
#   'data'],
#  ['petuum',
#   'new',
#   'platform',
#   'distributed',
#   'machine',
#   'learning',
#   'big',
#   'data'],
#  ['special',
#   'issue',
#   'biomedical',
#   'big',
#   'data',
#   'understanding',
#   'learning',
#   'application'],
#  ['smart',
#   'monitoring',
#   'camera',
#   'driven',
#   'intelligent',
#   'processing',
#   'big',
#   'surveillance',
#   'video',
#   'data'],
#  ['distributed',
#   'feature',
#   'selection',
#   'efficient',
#   'economic',
#   'big',
#   'data',
#   'analysis'],
#  ['extended',
#   'spatio',
#   'temporal',
#   'granger',
#   'causality',
#   'model',
#   'air',
#   'quality',
#   'estimation',
#   'heterogeneous',
#   'urban',
#   'big',
#   'data'],
#  ['hdm', 'composable', 'framework', 'big', 'data', 'processing'],
#  ['index', 'ieee', 'transaction', 'big', 'data', 'vol'],
#  ['enhanced',
#   'visualization',
#   'method',
#   'aid',
#   'behavioral',
#   'trajectory',
#   'pattern',
#   'recognition',
#   'infrastructure',
#   'big',
#   'longitudinal',
#   'data'],
#  ['dip',
#   'svm',
#   'distribution',
#   'preserving',
#   'kernel',
#   'support',
#   'vector',
#   'machine',
#   'big',
#   'data'],
#  ['availability', 'modelling', 'assurance', 'big', 'data', 'computing'],
#  ['deduplication', 'encrypted', 'big', 'data', 'cloud'],
#  ['guest',
#   'editorial',
#   'special',
#   'issue',
#   'big',
#   'scholar',
#   'data',
#   'discovery',
#   'collaboration',
#   'continued'],
#  ['kvasir',
#   'scalable',
#   'provision',
#   'semantically',
#   'relevant',
#   'web',
#   'content',
#   'big',
#   'data',
#   'framework'],
#  ['perception',
#   'independent',
#   'financial',
#   'advisor',
#   'usefulness',
#   'big',
#   'data',
#   'context',
#   'decision',
#   'making',
#   'uk'],
#  ['optimized',
#   'deep',
#   'learning',
#   'eeg',
#   'big',
#   'data',
#   'seizure',
#   'prediction',
#   'bci',
#   'via',
#   'internet',
#   'thing'],
#  ['algorithmseer',
#   'system',
#   'extracting',
#   'searching',
#   'algorithm',
#   'scholarly',
#   'big',
#   'data'],
#  ['taxi',
#   'passenger',
#   'demand',
#   'modeling',
#   'based',
#   'big',
#   'data',
#   'roving',
#   'sensor',
#   'network'],
#  ['big', 'data', 'analytics', 'security', 'criminal', 'investigation'],
#  ['data', 'discretization', 'taxonomy', 'big', 'data', 'challenge'],
#  ['big',
#   'data',
#   'analytics',
#   'review',
#   'data',
#   'mining',
#   'model',
#   'small',
#   'medium',
#   'enterprise',
#   'transportation',
#   'sector'],
#  ['big', 'data', 'analytics', 'apache', 'spark'],
#  ['applying',
#   'big',
#   'data',
#   'analytics',
#   'support',
#   'kansei',
#   'engineering',
#   'hotel',
#   'service',
#   'development'],
#  ['big', 'data', 'analytics', 'swarm', 'intelligence'],
#  ['entity',
#   'deduplication',
#   'big',
#   'data',
#   'graph',
#   'scholarly',
#   'communication'],
#  ['special',
#   'issue',
#   'first',
#   'international',
#   'conference',
#   'big',
#   'data',
#   'smart',
#   'computing',
#   'bigcomp'],
#  ['big', 'data', 'fusion'],
#  ['big',
#   'data',
#   'cloud',
#   'computing',
#   'insight',
#   'computing',
#   'environment',
#   'mapreduce',
#   'programming',
#   'framework'],
#  ['big',
#   'data',
#   'big',
#   'result',
#   'knowledge',
#   'discovery',
#   'output',
#   'large',
#   'scale',
#   'analytics'],
#  ['data', 'mining', 'big', 'data'],
#  ['data',
#   'analysis',
#   'big',
#   'data',
#   'improving',
#   'map',
#   'shuffle',
#   'phase',
#   'hadoop',
#   'map',
#   'reduce'],
#  ['analysis',
#   'academic',
#   'librarian',
#   'competency',
#   'skill',
#   'implementation',
#   'big',
#   'data',
#   'analytics',
#   'library'],
#  ['big', 'data', 'always', 'yield', 'big', 'benefit'],
#  ['big', 'data', 'improves', 'care'],
#  ['big',
#   'data',
#   'analytics',
#   'enabled',
#   'cyber',
#   'physical',
#   'system',
#   'model',
#   'application'],
#  ['big',
#   'bigger',
#   'biggest',
#   'data',
#   'repository',
#   'balloon',
#   'unprecedented',
#   'level',
#   'coping',
#   'big',
#   'data'],
#  ['big', 'data', 'internet', 'thing', 'revised', 'knowledge', 'pyramid'],
#  ['handling',
#   'big',
#   'dimension',
#   'distrubted',
#   'data',
#   'warehouse',
#   'using',
#   'dws',
#   'technique'],
#  ['quality',
#   'assessment',
#   'peer',
#   'produced',
#   'content',
#   'knowledge',
#   'repository',
#   'using',
#   'big',
#   'data',
#   'social',
#   'network',
#   'case',
#   'implicit',
#   'collaboration',
#   'wikipedia'],
#  ['big',
#   'data',
#   'analytics',
#   'machine',
#   'learning',
#   'bayesian',
#   'learning',
#   'perspective',
#   'done'],
#  ['big', 'data', 'paradigm', 'status', 'privacy', 'security'],
#  ['big',
#   'data',
#   'technology',
#   'process',
#   'spatial',
#   'attribute',
#   'data',
#   'designing',
#   'operating',
#   'mine',
#   'engineering',
#   'system'],
#  ['towards',
#   'big',
#   'linked',
#   'data',
#   'large',
#   'scale',
#   'distributed',
#   'semantic',
#   'data',
#   'storage'],
#  ['memory', 'big', 'data', 'management', 'processing', 'survey'],
#  ['spatial', 'data', 'mining', 'perspective', 'big', 'data'],
#  ['big',
#   'data',
#   'big',
#   'analysis',
#   'perspective',
#   'geographical',
#   'condition',
#   'monitoring'],
#  ['practical', 'big', 'data'],
#  ['exploring',
#   'big',
#   'data',
#   'analysis',
#   'fundamental',
#   'scientific',
#   'problem'],
#  ['managing',
#   'big',
#   'data',
#   'coal',
#   'fired',
#   'power',
#   'plant',
#   'business',
#   'intelligence',
#   'framework'],
#  ['analytics',
#   'partner',
#   'allina',
#   'health',
#   'team',
#   'health',
#   'catalyst',
#   'garner',
#   'benefit',
#   'big',
#   'data'],
#  ['using', 'data', 'build', 'better', 'em', 'em', 'big', 'data'],
#  ['tensor',
#   'based',
#   'big',
#   'data',
#   'management',
#   'scheme',
#   'dimensionality',
#   'reduction',
#   'problem',
#   'smart',
#   'grid',
#   'system',
#   'sdn',
#   'perspective'],
#  ['michael',
#   'buck',
#   'talk',
#   'living',
#   'dream',
#   'bioinformaticist',
#   'emerging',
#   'alternative',
#   'big',
#   'data',
#   'warehouse'],
#  ['eu', 'data', 'privacy', 'law', 'face', 'big', 'shake'],
#  ['scalable',
#   'multi',
#   'data',
#   'source',
#   'based',
#   'recursive',
#   'approximation',
#   'approach',
#   'fast',
#   'error',
#   'recovery',
#   'big',
#   'sensing',
#   'data',
#   'cloud'],
#  ['flexible', 'heavy', 'tailed', 'distribution', 'big', 'data'],
#  ['semantics',
#   'meet',
#   'big',
#   'data',
#   'formal',
#   'model',
#   'practical',
#   'issue',
#   'novel',
#   'paradigm'],
#  ['forecasting', 'big', 'data', 'review'],
#  ['china', 'deal', 'big', 'data'],
#  ['detailed',
#   'review',
#   'prominent',
#   'compression',
#   'method',
#   'used',
#   'reducing',
#   'data',
#   'volume',
#   'big',
#   'data'],
#  ['mongodb',
#   'based',
#   'modular',
#   'ontology',
#   'building',
#   'big',
#   'data',
#   'integration'],
#  ['scalable',
#   'data',
#   'chunk',
#   'similarity',
#   'based',
#   'compression',
#   'approach',
#   'efficient',
#   'big',
#   'sensing',
#   'data',
#   'processing',
#   'cloud'],
#  ['fuzzy',
#   'rule',
#   'based',
#   'classification',
#   'system',
#   'big',
#   'data',
#   'mapreduce',
#   'granularity',
#   'analysis'],
#  ['cell',
#   'phone',
#   'big',
#   'data',
#   'compute',
#   'mobility',
#   'scenario',
#   'future',
#   'smart',
#   'city'],
#  ['semantics', 'aware', 'approach', 'big', 'data', 'engineering'],
#  ['smart', 'city', 'big', 'data', 'analytics', 'advanced', 'review'],
#  ['watchdog',
#   'approach',
#   'name',
#   'matching',
#   'algorithm',
#   'big',
#   'data',
#   'risk',
#   'intelligence'],
#  ['intelligent',
#   'approach',
#   'big',
#   'data',
#   'analytics',
#   'sustainable',
#   'retail',
#   'environment',
#   'using',
#   'apriori',
#   'mapreduce',
#   'framework'],
#  ['organisation', 'leverage', 'big', 'data', 'maturity', 'model'],
#  ['effective',
#   'efficient',
#   'distributed',
#   'management',
#   'big',
#   'clinical',
#   'data',
#   'framework'],
#  ['simd',
#   'parallel',
#   'mcmc',
#   'sampling',
#   'application',
#   'big',
#   'data',
#   'bayesian',
#   'analytics'],
#  ['framework',
#   'evaluating',
#   'design',
#   'methodology',
#   'big',
#   'data',
#   'warehouse',
#   'measurement',
#   'design',
#   'process'],
#  ['stakeholder',
#   'perception',
#   'word',
#   'mouth',
#   'csr',
#   'dynamic',
#   'big',
#   'data',
#   'analysis',
#   'twitter'],
#  ['efficient', 'skyline', 'computation', 'big', 'data'],
#  ['incremental', 'query', 'processing', 'big', 'data', 'stream'],
#  ['barrier',
#   'embedding',
#   'big',
#   'data',
#   'solution',
#   'smart',
#   'factory',
#   'insight',
#   'sap',
#   'consultant'],
#  ['extracting',
#   'kernel',
#   'dataset',
#   'big',
#   'sensory',
#   'data',
#   'wireless',
#   'sensor',
#   'network'],
#  ['insight', 'application', 'big', 'data', 'analytics', 'healthcare'],
#  ['quantile',
#   'regression',
#   'big',
#   'data',
#   'divide',
#   'conquer',
#   'based',
#   'strategy'],
#  ['review',
#   'sentiment',
#   'discovery',
#   'analysis',
#   'educational',
#   'big',
#   'data'],
#  ['mr', 'plot', 'big', 'data', 'tool', 'distinguishing', 'distribution'],
#  ['overview',
#   'online',
#   'based',
#   'platform',
#   'sharing',
#   'analyzing',
#   'electrophysiology',
#   'data',
#   'big',
#   'data',
#   'perspective'],
#  ['holistic', 'view', 'big', 'data'],
#  ['modeling',
#   'evaluating',
#   'effect',
#   'big',
#   'data',
#   'storage',
#   'resource',
#   'allocation',
#   'global',
#   'scale',
#   'cloud',
#   'architecture'],
#  ['scalable',
#   'machine',
#   'learning',
#   'algorithm',
#   'big',
#   'data',
#   'analytics',
#   'comprehensive',
#   'review'],
#  ['advancing', 'science', 'technology', 'big', 'data', 'analytics'],
#  ['mapreduce',
#   'incremental',
#   'mapreduce',
#   'mining',
#   'evolving',
#   'big',
#   'data'],
#  ['multi',
#   'step',
#   'nonlinear',
#   'dimension',
#   'reduction',
#   'approach',
#   'application',
#   'big',
#   'data'],
#  ['efficient',
#   'distributed',
#   'generalized',
#   'canonical',
#   'correlation',
#   'analysis',
#   'big',
#   'multiview',
#   'data'],
#  ['web',
#   'medium',
#   'stock',
#   'market',
#   'survey',
#   'future',
#   'direction',
#   'big',
#   'data',
#   'perspective'],
#  ['k',
#   'nearest',
#   'neighbour',
#   'join',
#   'big',
#   'data',
#   'mapreduce',
#   'theoretical',
#   'experimental',
#   'analysis'],
#  ['haery',
#   'hadoop',
#   'based',
#   'query',
#   'system',
#   'accumulative',
#   'high',
#   'dimensional',
#   'data',
#   'model',
#   'big',
#   'data'],
#  ['va',
#   'store',
#   'virtual',
#   'approximate',
#   'store',
#   'approach',
#   'supporting',
#   'repetitive',
#   'big',
#   'data',
#   'genome',
#   'sequence',
#   'analysis'],
#  ['feasibility', 'distributed', 'kernel', 'regression', 'big', 'data'],
#  ['scalable',
#   'algorithm',
#   'nearest',
#   'neighbor',
#   'join',
#   'big',
#   'trajectory',
#   'data'],
#  ['gamma',
#   'matrix',
#   'summarize',
#   'dense',
#   'sparse',
#   'data',
#   'set',
#   'big',
#   'data',
#   'analytics'],
#  ['uncertainty',
#   'measure',
#   'fusion',
#   'rule',
#   'conflict',
#   'evidence',
#   'big',
#   'data',
#   'via',
#   'dempster',
#   'shafer',
#   'theory'],
#  ['pcce',
#   'twitter',
#   'personality',
#   'based',
#   'communicative',
#   'community',
#   'extraction',
#   'system',
#   'big',
#   'data'],
#  ['mining', 'suspicious', 'tax', 'evasion', 'group', 'big', 'data'],
#  ['bias', 'correction', 'small', 'sample', 'big', 'data'],
#  ['novel', 'pipeline', 'approach', 'efficient', 'big', 'data', 'broadcasting'],
#  ['enhanced',
#   'graph',
#   'transforming',
#   'v',
#   'algorithm',
#   'non',
#   'simple',
#   'graph',
#   'big',
#   'data',
#   'pre',
#   'processing'],
#  ['big',
#   'business',
#   'big',
#   'government',
#   'big',
#   'legal',
#   'question',
#   'big',
#   'data',
#   'stay',
#   'mean',
#   'ip',
#   'todd',
#   'vare',
#   'michael',
#   'mattioli',
#   'look',
#   'big',
#   'data',
#   'protected',
#   'u',
#   'ask',
#   'whether',
#   'thrive',
#   'existing',
#   'legal',
#   'framework'],
#  ['big',
#   'data',
#   'creating',
#   'new',
#   'knowledge',
#   'support',
#   'decision',
#   'making',
#   'practical',
#   'example',
#   'big',
#   'data',
#   'use',
#   'consequence',
#   'using',
#   'big',
#   'data',
#   'decision',
#   'support'],
#  ['big',
#   'data',
#   'small',
#   'data',
#   'concept',
#   'big',
#   'data',
#   'hard',
#   'quantify',
#   'good',
#   'remember',
#   'hat',
#   'big',
#   'data',
#   'made',
#   'small',
#   'data'],
#  ['big',
#   'data',
#   'big',
#   'deal',
#   'e',
#   'amp',
#   'p',
#   'industry',
#   'must',
#   'work',
#   'big',
#   'data',
#   'meet',
#   'future',
#   'demand',
#   'growing',
#   'global',
#   'population'],
#  ['big',
#   'security',
#   'big',
#   'data',
#   'addressing',
#   'security',
#   'challenge',
#   'big',
#   'data',
#   'infrastructure'],
#  ['big',
#   'data',
#   'big',
#   'knowledge',
#   'big',
#   'data',
#   'personalized',
#   'healthcare'],
#  ['big',
#   'bang',
#   'big',
#   'data',
#   'big',
#   'iron',
#   'fifteen',
#   'year',
#   'cosmic',
#   'microwave',
#   'background',
#   'data',
#   'analysis',
#   'nersc'],
#  ['big',
#   'data',
#   'big',
#   'impact',
#   'four',
#   'year',
#   'computerworld',
#   'honor',
#   'laureate',
#   'using',
#   'big',
#   'data',
#   'battle',
#   'effect',
#   'unemployment',
#   'climate',
#   'change',
#   'raise',
#   'social',
#   'awareness',
#   'help',
#   'risk',
#   'student'],
#  ['big',
#   'data',
#   'big',
#   'gain',
#   'big',
#   'pain',
#   'lawyer',
#   'huge',
#   'quantity',
#   'data',
#   'offer',
#   'potential',
#   'boon',
#   'lawyer',
#   'cause',
#   'headache'],
#  ['big',
#   'data',
#   'big',
#   'money',
#   'mining',
#   'big',
#   'data',
#   'make',
#   'major',
#   'difference',
#   'even',
#   'value',
#   'spinning',
#   'data'],
#  ['big',
#   'data',
#   'risk',
#   'management',
#   'financial',
#   'service',
#   'industry',
#   'provides',
#   'lesson',
#   'prevent',
#   'big',
#   'data',
#   'becoming',
#   'big',
#   'problem'],
#  ['big',
#   'data',
#   'big',
#   'job',
#   'company',
#   'embrace',
#   'big',
#   'data',
#   'market',
#   'high',
#   'level',
#   'strategist',
#   'communicator',
#   'chop',
#   'snag',
#   'big',
#   'data',
#   'job'],
#  ['big',
#   'data',
#   'driven',
#   'smart',
#   'energy',
#   'management',
#   'big',
#   'data',
#   'big',
#   'insight'],
#  ['big',
#   'data',
#   'big',
#   'gain',
#   'understanding',
#   'link',
#   'big',
#   'data',
#   'analytics',
#   'innovation'],
#  ['big',
#   'data',
#   'big',
#   'question',
#   'emerging',
#   'big',
#   'data',
#   'technology',
#   'work',
#   'old',
#   'school',
#   'company',
#   'sears',
#   'trying'],
#  ['big',
#   'data',
#   'mean',
#   'big',
#   'knowledge',
#   'km',
#   'perspective',
#   'big',
#   'data',
#   'analytics'],
#  ['big',
#   'data',
#   'big',
#   'deal',
#   'competition',
#   'law',
#   'approach',
#   'big',
#   'data'],
#  ['think',
#   'big',
#   'big',
#   'data',
#   'identifying',
#   'suitable',
#   'big',
#   'data',
#   'strategy',
#   'corporate',
#   'environment'],
#  ['cognitive',
#   'big',
#   'data',
#   'survey',
#   'review',
#   'big',
#   'data',
#   'research',
#   'implication',
#   'really',
#   'new',
#   'big',
#   'data'],
#  ['digital',
#   'data',
#   'administrative',
#   'data',
#   'survey',
#   'compared',
#   'updating',
#   'classical',
#   'toolbox',
#   'assessing',
#   'data',
#   'quality',
#   'big',
#   'data',
#   'exemplified',
#   'generation',
#   'corruption',
#   'data'],
#  ['big',
#   'data',
#   'meet',
#   'software',
#   'defined',
#   'networking',
#   'sdn',
#   'big',
#   'data',
#   'big',
#   'data',
#   'sdn'],
#  ['big',
#   'data',
#   'healthcare',
#   'big',
#   'hope',
#   'big',
#   'hype',
#   'early',
#   'health',
#   'technology',
#   'assessment',
#   'big',
#   'data',
#   'analytics',
#   'healthcare'],
#  ['big',
#   'data',
#   'healthcare',
#   'big',
#   'hope',
#   'big',
#   'hype',
#   'early',
#   'health',
#   'technology',
#   'assessment',
#   'big',
#   'data',
#   'analytics',
#   'healthcare'],
#  ['big',
#   'data',
#   'mean',
#   'big',
#   'knowledge',
#   'integration',
#   'big',
#   'data',
#   'analysis',
#   'conceptual',
#   'model',
#   'social',
#   'commerce',
#   'research'],
#  ['snapshot',
#   'big',
#   'data',
#   'trend',
#   'latin',
#   'america',
#   'latin',
#   'american',
#   'country',
#   'long',
#   'way',
#   'go',
#   'using',
#   'big',
#   'data',
#   'analytics',
#   'time',
#   'develop',
#   'regional',
#   'strategy',
#   'big',
#   'data'],
#  ['politics', 'big', 'data', 'big', 'data', 'big', 'brother'],
#  ['guest',
#   'editorial',
#   'big',
#   'big',
#   'data',
#   'finding',
#   'space',
#   'peril',
#   'big',
#   'data'],
#  ['politics',
#   'big',
#   'data',
#   'big',
#   'data',
#   'big',
#   'brother',
#   'r',
#   'tnani',
#   'schneidern',
#   'green',
#   'ed',
#   'londonroutledge',
#   'pp',
#   'isbn'],
#  ['case',
#   'big',
#   'data',
#   'new',
#   'york',
#   'city',
#   'kalvi',
#   'human',
#   'project',
#   'aim',
#   'use',
#   'big',
#   'data',
#   'resolving',
#   'big',
#   'health',
#   'question'],
#  ['listen',
#   'cmos',
#   'time',
#   'turned',
#   'big',
#   'data',
#   'big',
#   'action',
#   'big',
#   'data',
#   'present',
#   'unlimited',
#   'opportunity',
#   'marketer',
#   'must',
#   'know',
#   'use',
#   'interpreting',
#   'auctioning',
#   'insight',
#   'correctly',
#   'marketer',
#   'brand',
#   'see',
#   'consumer',
#   'coming',
#   'back',
#   'time',
#   'time'],
#  ['framework',
#   'identifying',
#   'analyzing',
#   'major',
#   'issue',
#   'implementing',
#   'big',
#   'data',
#   'data',
#   'analytics',
#   'e',
#   'learning',
#   'introduction',
#   'special',
#   'issue',
#   'big',
#   'data',
#   'data',
#   'analytics'],
#  ['big',
#   'data',
#   'migration',
#   'data',
#   'center',
#   'online',
#   'cloud',
#   'environment'],
#  ['big', 'plateau', 'big', 'data', 'big', 'island'],
#  ['big', 'data', 'big', 'tech', 'protecting', 'patient', 'privacy'],
#  ['data', 'data', 'big', 'data'],
#  ['big',
#   'data',
#   'sparse',
#   'data',
#   'diverse',
#   'scientific',
#   'benchmark',
#   'reveal',
#   'optimization',
#   'imperative',
#   'implicit',
#   'membrane',
#   'energy',
#   'function'],
#  ['big', 'hope', 'big', 'data'],
#  ['big',
#   'data',
#   'promise',
#   'pay',
#   'big',
#   'dividend',
#   'swd',
#   'inc',
#   'continuous',
#   'improvement',
#   'minded',
#   'provider',
#   'metal',
#   'finishing',
#   'fastener',
#   'sorting',
#   'service',
#   'new',
#   'data',
#   'discovery',
#   'analysis',
#   'software',
#   'allows',
#   'swd',
#   'management',
#   'unlock',
#   'new',
#   'pathway',
#   'improved',
#   'performance',
#   'serf',
#   'foundation',
#   'customer',
#   'communication',
#   'strategy',
#   'future'],
#  ['big',
#   'data',
#   'digital',
#   'revolution',
#   'continues',
#   'unleash',
#   'ever',
#   'data',
#   'source',
#   'upon',
#   'world',
#   'new',
#   'report',
#   'cii',
#   'ordnance',
#   'survey',
#   'look',
#   'information',
#   'harnessed'],
#  ['big',
#   'help',
#   'big',
#   'data',
#   'large',
#   'health',
#   'system',
#   'like',
#   'mayo',
#   'clinic',
#   'intermountain',
#   'health',
#   'care',
#   'turning',
#   'outside',
#   'firm',
#   'boost',
#   'analytical',
#   'capability'],
#  ['data',
#   'centre',
#   'next',
#   'big',
#   'challenge',
#   'really',
#   'know',
#   'data',
#   'centre'],
#  ['big', 'data', 'big', 'business', 'statistician', 'join'],
#  ['big', 'data', 'big', 'opportunity'],
#  ['big', 'data', 'big', 'pharma'],
#  ['data',
#   'science',
#   'predictive',
#   'analytics',
#   'big',
#   'data',
#   'revolution',
#   'transform',
#   'supply',
#   'chain',
#   'design',
#   'management'],
#  ['big',
#   'data',
#   'reform',
#   'european',
#   'data',
#   'protection',
#   'framework',
#   'overview',
#   'potential',
#   'concern',
#   'associated',
#   'proposal',
#   'risk',
#   'management',
#   'based',
#   'approach',
#   'concept',
#   'personal',
#   'data'],
#  ['big', 'idea', 'big', 'data', 'president', 'message'],
#  ['big', 'data', 'big', 'unintended', 'consequence'],
#  ['data',
#   'analytics',
#   'machine',
#   'learning',
#   'smart',
#   'process',
#   'manufacturing',
#   'recent',
#   'advance',
#   'perspective',
#   'big',
#   'data',
#   'era'],
#  ['big',
#   'data',
#   'revolution',
#   'open',
#   'source',
#   'data',
#   'processing',
#   'platform',
#   'fan',
#   'among',
#   'web',
#   'giant',
#   'low',
#   'cost',
#   'scalability',
#   'flexibility',
#   'hadoop',
#   'headed',
#   'wider',
#   'use'],
#  ['big',
#   'data',
#   'e',
#   'amp',
#   'p',
#   'real',
#   'time',
#   'adaptive',
#   'analytics',
#   'data',
#   'flow',
#   'architecture'],
#  ['big',
#   'data',
#   'utility',
#   'seek',
#   'extract',
#   'value',
#   'technology',
#   'asset',
#   'smart',
#   'grid',
#   'metering',
#   'data',
#   'becoming',
#   'gold',
#   'mine',
#   'insight',
#   'improve',
#   'service',
#   'save',
#   'money'],
#  ['big',
#   'data',
#   'little',
#   'data',
#   'data',
#   'scholarship',
#   'networked',
#   'world',
#   'christine',
#   'l',
#   'borgman'],
#  ['big', 'data', 'intensive', 'care', 'unit', 'closing', 'data', 'loop'],
#  ['data', 'clustering', 'using', 'big', 'bang', 'big', 'crunch', 'algorithm'],
#  ['big',
#   'data',
#   'access',
#   'infrastructure',
#   'modern',
#   'biology',
#   'case',
#   'study',
#   'data',
#   'repository',
#   'utility'],
#  ['big', 'data', 'legal', 'framework', 'data', 'quality'],
#  ['data', 'daze', 'big', 'data', 'surrounded', 'hype', 'substance', 'behind'],
#  ['data', 'management', 'open', 'approach', 'big', 'data'],
#  ['big',
#   'work',
#   'progress',
#   'big',
#   'data',
#   'public',
#   'private',
#   'forum',
#   'public',
#   'sector'],
#  ['big', 'data', 'analytics', 'transforming', 'data', 'action'],
#  ['big',
#   'data',
#   'role',
#   'health',
#   'economics',
#   'outcome',
#   'research',
#   'collection',
#   'perspective',
#   'data',
#   'source',
#   'measurement',
#   'analysis'],
#  ['big', 'data', 'begets', 'big', 'database', 'theory'],
#  ['big', 'data', 'big', 'handprint'],
#  ['data',
#   'management',
#   'based',
#   'big',
#   'data',
#   'technology',
#   'implementing',
#   'remote',
#   'vehicle',
#   'diagnostic',
#   'system'],
#  ['data',
#   'quality',
#   'management',
#   'data',
#   'usage',
#   'experience',
#   'acquisition',
#   'intention',
#   'big',
#   'data',
#   'analytics'],
#  ['big',
#   'best',
#   'big',
#   'always',
#   'best',
#   'world',
#   'data',
#   'jay',
#   'inamdar',
#   'explains'],
#  ['big', 'data', 'big', 'opportunity', 'big', 'challenge'],
#  ['data',
#   'analytics',
#   'stat',
#   'university',
#   'pittsburgh',
#   'medical',
#   'center',
#   'invests',
#   'million',
#   'big',
#   'data',
#   'analytics'],
#  ['big',
#   'data',
#   'knowledge',
#   'common',
#   'pitfall',
#   'transcriptomics',
#   'data',
#   'analysis',
#   'representation'],
#  ['big',
#   'universe',
#   'big',
#   'data',
#   'machine',
#   'learning',
#   'image',
#   'analysis',
#   'astronomy'],
#  ['big',
#   'data',
#   'analytics',
#   'expert',
#   'interview',
#   'bipin',
#   'chadha',
#   'data',
#   'scientist',
#   'united',
#   'service',
#   'automobile',
#   'association',
#   'usaa'],
#  ['data', 'flood', 'navy', 'want', 'big', 'data'],
#  ['big',
#   'data',
#   'bigger',
#   'outcome',
#   'healthcare',
#   'embracing',
#   'big',
#   'data',
#   'movement',
#   'could',
#   'revolutionize'],
#  ['big',
#   'daddy',
#   'big',
#   'data',
#   'ge',
#   'stake',
#   'claim',
#   'industrial',
#   'internet',
#   'would',
#   'extract',
#   'data',
#   'boost',
#   'machine',
#   'efficiency'],
#  ['big',
#   'data',
#   'biggest',
#   'change',
#   'brand',
#   'since',
#   'broadcast',
#   'medium',
#   'gemma',
#   'carver',
#   'group',
#   'marketing',
#   'director',
#   'restaurant',
#   'reservation',
#   'service',
#   'livebookings',
#   'reveals',
#   'importance',
#   'mobile',
#   'plan',
#   'increase',
#   'personalisation',
#   'dealing',
#   'big',
#   'data'],
#  ['big', 'question', 'big', 'data'],
#  ['big', 'data', 'challenge', 'data', 'management', 'perspective'],
#  ['big', 'data', 'big', 'challenge'],
#  ['big',
#   'data',
#   'learning',
#   'analytics',
#   'big',
#   'potential',
#   'improve',
#   'e',
#   'learning'],
#  ['big', 'data', 'big', 'opportunity', 'big', 'challenge'],
#  ['big', 'data', 'big', 'money', 'role', 'data', 'financial', 'sector'],
#  ['big', 'data', 'big', 'opportunity', 'librarian'],
#  ['big', 'data', 'data', 'eco', 'system'],
#  ['big',
#   'fight',
#   'big',
#   'data',
#   'tech',
#   'giant',
#   'vie',
#   'consumer',
#   'information'],
#  ['big',
#   'data',
#   'analyse',
#   'first',
#   'series',
#   'katharine',
#   'bagshaw',
#   'fca',
#   'examines',
#   'scope',
#   'use',
#   'data',
#   'analytics',
#   'audit'],
#  ['big', 'data', 'analytics', 'data', 'science', 'ci', 'president', 'message'],
#  ['big',
#   'data',
#   'creates',
#   'big',
#   'opportunity',
#   'promise',
#   'challenge',
#   'large',
#   'veterinary',
#   'health',
#   'datasets'],
#  ['big', 'dilemma', 'big', 'data', 'threat', 'opportunity', 'finance'],
#  ['big', 'money', 'big', 'data'],
#  ['big',
#   'data',
#   'data',
#   'analytics',
#   'research',
#   'metaphor',
#   'value',
#   'space',
#   'collective',
#   'wisdom',
#   'human',
#   'decision',
#   'making',
#   'smart',
#   'machine'],
#  ['data',
#   'intelligence',
#   'local',
#   'government',
#   'assessing',
#   'benefit',
#   'barrier',
#   'use',
#   'big',
#   'data',
#   'public',
#   'sector'],
#  ['big',
#   'data',
#   'leveraging',
#   'big',
#   'data',
#   'improve',
#   'subscriber',
#   'service',
#   'management'],
#  ['data',
#   'management',
#   'financial',
#   'regulation',
#   'using',
#   'big',
#   'data',
#   'approach',
#   'regulatory',
#   'compliance'],
#  ['big',
#   'data',
#   'little',
#   'optic',
#   'intelligent',
#   'use',
#   'data',
#   'help',
#   'create',
#   'responsive',
#   'patient',
#   'service'],
#  ['big',
#   'data',
#   'pre',
#   'processing',
#   'method',
#   'vehicle',
#   'driving',
#   'data',
#   'using',
#   'mapreduce',
#   'technique'],
#  ['big',
#   'data',
#   'manage',
#   'drown',
#   'exponential',
#   'growth',
#   'data',
#   'challenging',
#   'ability',
#   'process',
#   'effectively',
#   'exploit',
#   'contains'],
#  ['big', 'data', 'big', 'future'],
#  ['big', 'data', 'big', 'data', 'mean', 'implication', 'marketer', 'brand'],
#  ['big', 'data', 'healthcare', 'discussion', 'big', 'challenge'],
#  ['big', 'search', 'big', 'data'],
#  ['data',
#   'analytics',
#   'big',
#   'data',
#   'construction',
#   'project',
#   'asset',
#   'management'],
#  ['big',
#   'data',
#   'big',
#   'borther',
#   'big',
#   'buck',
#   'equifax',
#   'creating',
#   'new',
#   'analytics',
#   'product',
#   'billion',
#   'business',
#   'consumer',
#   'record',
#   'worldwide',
#   'cio',
#   'innovation',
#   'edge'],
#  ['data',
#   'driven',
#   'decision',
#   'making',
#   'precision',
#   'agriculture',
#   'rise',
#   'big',
#   'data',
#   'agricultural',
#   'system'],
#  ['big',
#   'heart',
#   'data',
#   'advancing',
#   'health',
#   'informatics',
#   'data',
#   'sharing',
#   'cardiovascular',
#   'imaging'],
#  ['big',
#   'data',
#   'challenge',
#   'indexing',
#   'large',
#   'volume',
#   'heterogeneous',
#   'eo',
#   'datasets',
#   'effective',
#   'data',
#   'discovery'],
#  ['big',
#   'data',
#   'meet',
#   'material',
#   'science',
#   'training',
#   'future',
#   'generation',
#   'capitalizing',
#   'promise',
#   'big',
#   'data',
#   'require',
#   'material',
#   'scientist',
#   'trained',
#   'data',
#   'informatics',
#   'several',
#   'university',
#   'answering',
#   'call'],
#  ['big', 'data', 'big', 'bias', 'drug', 'safety'],
#  ['big', 'data', 'expert', 'discus', 'customer', 'data', 'treatment'],
#  ['big',
#   'data',
#   'big',
#   'metadata',
#   'quantitative',
#   'study',
#   'science',
#   'workflow',
#   'model',
#   'big',
#   'scientometrics'],
#  ['big', 'data', 'big', 'analytics', 'big', 'opportunity'],
#  ['big',
#   'data',
#   'interpolation',
#   'efficient',
#   'sampling',
#   'alternative',
#   'sensor',
#   'data',
#   'aggregation',
#   'extended',
#   'abstract'],
#  ['big',
#   'data',
#   'little',
#   'data',
#   'data',
#   'scholarship',
#   'networked',
#   'world'],
#  ['big', 'data', 'open', 'data', 'midata', 'linked'],
#  ['big', 'book', 'big', 'data', 'reading', 'literary', 'history'],
#  ['big',
#   'data',
#   'preliminary',
#   'analysis',
#   'framework',
#   'easier',
#   'data',
#   'sharing',
#   'discovery'],
#  ['data',
#   'experience',
#   'marktforschung',
#   'den',
#   'zeiten',
#   'von',
#   'big',
#   'data'],
#  ['big',
#   'data',
#   'company',
#   'ensure',
#   'public',
#   'confidence',
#   'arrival',
#   'big',
#   'data'],
#  ['big',
#   'data',
#   'friend',
#   'foe',
#   'digital',
#   'advertising',
#   'five',
#   'way',
#   'marketer',
#   'use',
#   'digital',
#   'big',
#   'data',
#   'advantage'],
#  ['big', 'data', 'need', 'big', 'planning'],
#  ['data',
#   'source',
#   'selection',
#   'information',
#   'integration',
#   'big',
#   'data',
#   'era'],
#  ['big',
#   'data',
#   'analytics',
#   'sentiment',
#   'analysis',
#   'twitter',
#   'data',
#   'using',
#   'clustering',
#   'technique'],
#  ['big',
#   'data',
#   'opportunity',
#   'challenge',
#   'discussion',
#   'data',
#   'analytics',
#   'perspective',
#   'discussion',
#   'forum'],
#  ['big',
#   'data',
#   'data',
#   'driven',
#   'intelligent',
#   'predictive',
#   'algorithm',
#   'support',
#   'creativity',
#   'industrial',
#   'engineering'],
#  ['big',
#   'data',
#   'cause',
#   'big',
#   'mistake',
#   'using',
#   'societas',
#   'europaea',
#   'herpetologica',
#   'atlas',
#   'sillero',
#   'et',
#   'al',
#   'distribution',
#   'emys',
#   'orbicularis',
#   'misunderstood'],
#  ['big',
#   'data',
#   'big',
#   'new',
#   'market',
#   'insight',
#   'washington',
#   'state',
#   'legal',
#   'cannabis',
#   'market'],
#  ['big',
#   'data',
#   'big',
#   'city',
#   'promise',
#   'limitation',
#   'improved',
#   'measure',
#   'urban',
#   'life'],
#  ['data',
#   'locality',
#   'aware',
#   'big',
#   'data',
#   'query',
#   'evaluation',
#   'distributed',
#   'cloud'],
#  ['big',
#   'data',
#   'opportunity',
#   'challenge',
#   'discussion',
#   'data',
#   'analytics',
#   'perspective'],
#  ['big', 'building', 'data', 'big', 'data', 'platform', 'smart', 'building'],
#  ['big',
#   'data',
#   'big',
#   'challenge',
#   'researcher',
#   'begin',
#   'analyzing',
#   'massive',
#   'datasets',
#   'opportunity',
#   'chaos',
#   'error',
#   'multiply'],
#  ['big',
#   'data',
#   'little',
#   'individual',
#   'considering',
#   'human',
#   'side',
#   'big',
#   'data'],
#  ['big', 'data', 'analytics', 'big', 'data', 'science', 'survey'],
#  ['big',
#   'small',
#   'data',
#   'analytics',
#   'brings',
#   'home',
#   'bacon',
#   'invested',
#   'creation',
#   'storage',
#   'data',
#   'use',
#   'analytics',
#   'derive',
#   'insight',
#   'information'],
#  ['big', 'genetic', 'data', 'big', 'data', 'protection', 'challenge'],
#  ['big', 'data', 'meet', 'big', 'science'],
#  ['data',
#   'protection',
#   'era',
#   'big',
#   'data',
#   'challenge',
#   'posed',
#   'big',
#   'personal',
#   'data'],
#  ['data', 'driven', 'medicinal', 'chemistry', 'era', 'big', 'data'],
#  ['big', 'data', 'biology', 'next', 'big', 'hype'],
#  ['big',
#   'data',
#   'early',
#   'building',
#   'block',
#   'learning',
#   'health',
#   'system',
#   'fall',
#   'place'],
#  ['big',
#   'data',
#   'takeaway',
#   'report',
#   'two',
#   'hour',
#   'special',
#   'event',
#   'ucsd',
#   'campus',
#   'called',
#   'big',
#   'data',
#   'work',
#   'conversation',
#   'expert'],
#  ['data',
#   'quality',
#   'data',
#   'science',
#   'predictive',
#   'analytics',
#   'big',
#   'data',
#   'supply',
#   'chain',
#   'management',
#   'introduction',
#   'problem',
#   'suggestion',
#   'research',
#   'application'],
#  ['data', 'privacy', 'big', 'data', 'compliance', 'issue', 'consideration'],
#  ['big',
#   'data',
#   'analytic',
#   'big',
#   'step',
#   'patient',
#   'management',
#   'care',
#   'puerto',
#   'rico'],
#  ['big',
#   'data',
#   'third',
#   'final',
#   'article',
#   'series',
#   'jonathan',
#   'kettleborough',
#   'highlight',
#   'number',
#   'emerging',
#   'issue',
#   'potential',
#   'pitfall',
#   'aware',
#   'using',
#   'big',
#   'data'],
#  ['big',
#   'data',
#   'politics',
#   'open',
#   'data',
#   'case',
#   'health',
#   'care',
#   'data',
#   'england'],
#  ['big', 'data', 'data'],
#  ['big', 'data', 'challenge', 'advance', 'highlight', 'big', 'issue'],
#  ['data',
#   'barn',
#   'ambient',
#   'intelligence',
#   'cloud',
#   'computing',
#   'tacit',
#   'epistemology',
#   'linguistic',
#   'representation',
#   'big',
#   'data'],
#  ['data',
#   'relationship',
#   'building',
#   'vendor',
#   'drug',
#   'researcher',
#   'put',
#   'logic',
#   'science',
#   'work',
#   'vetting',
#   'big',
#   'data'],
#  ['big', 'data', 'big', 'mistake'],
#  ['big',
#   'data',
#   'healthy',
#   'city',
#   'using',
#   'location',
#   'aware',
#   'technology',
#   'open',
#   'data',
#   'urban',
#   'model',
#   'design',
#   'healthier',
#   'built',
#   'environment'],
#  ['data', 'big', 'data', 'database', 'semantics'],
#  ['big',
#   'data',
#   'big',
#   'compute',
#   'technology',
#   'realm',
#   'possibility',
#   'emergence',
#   'real',
#   'time',
#   'risk',
#   'enterprise',
#   'capital',
#   'market',
#   'industry'],
#  ['big',
#   'data',
#   'big',
#   'decision',
#   'coming',
#   'change',
#   'technology',
#   'investment'],
#  ['data',
#   'quality',
#   'issue',
#   'concerning',
#   'statistical',
#   'data',
#   'gathering',
#   'supported',
#   'big',
#   'data',
#   'technology'],
#  ['big',
#   'data',
#   'trend',
#   'stroke',
#   'epidemiology',
#   'united',
#   'state',
#   'good',
#   'data'],
#  ['big', 'data', 'learning', 'health', 'system'],
#  ['big',
#   'data',
#   'navigating',
#   'federal',
#   'aim',
#   'state',
#   'privacy',
#   'law',
#   'potential',
#   'pitfall',
#   'applying',
#   'big',
#   'data',
#   'healthcare',
#   'legal',
#   'expert',
#   'law',
#   'firm',
#   'foley',
#   'amp',
#   'lardner',
#   'offer',
#   'advice',
#   'complying',
#   'federal',
#   'state',
#   'privacy',
#   'law'],
#  ['big', 'change', 'big', 'data'],
#  ['big',
#   'data',
#   'sport',
#   'digital',
#   'divide',
#   'theorizing',
#   'athlete',
#   'might',
#   'respond',
#   'big',
#   'data',
#   'monitoring'],
#  ['big', 'bigger', 'biggest', 'big', 'data'],
#  ['data', 'intelligence', 'context', 'big', 'data', 'survey'],
#  ['big',
#   'data',
#   'cryoem',
#   'automated',
#   'collection',
#   'processing',
#   'accessibility',
#   'em',
#   'data'],
#  ['data', 'asset', 'oil', 'gas', 'sector', 'learn', 'industry', 'big', 'data'],
#  ['big',
#   'data',
#   'small',
#   'data',
#   'data',
#   'sharing',
#   'long',
#   'tail',
#   'neuroscience'],
#  ['data',
#   'access',
#   'control',
#   'data',
#   'exchanging',
#   'supporting',
#   'big',
#   'data',
#   'arena'],
#  ['big',
#   'data',
#   'mining',
#   'turning',
#   'data',
#   'mining',
#   'predictive',
#   'analytics',
#   'large',
#   'scale',
#   'v',
#   'data',
#   'future',
#   'challenge',
#   'knowledge',
#   'discovery'],
#  ['big', 'data', 'promise', 'big', 'opportunity'],
#  ['big',
#   'data',
#   'v',
#   'accurate',
#   'data',
#   'health',
#   'research',
#   'large',
#   'scale',
#   'physical',
#   'activity',
#   'monitoring',
#   'smartphones',
#   'wearable',
#   'device',
#   'risk',
#   'unconscious',
#   'bias'],
#  ['data', 'stream', 'classification', 'big', 'data', 'analytics'],
#  ['big', 'data', 'privacy', 'public', 'organization', 'adopt', 'big', 'data'],
#  ['big',
#   'data',
#   'individual',
#   'architectural',
#   'design',
#   'process',
#   'combining',
#   'individual',
#   'data',
#   'architect',
#   'toolset'],
#  ['big', 'data', 'operation', 'basis', 'benchmarking', 'data', 'grid'],
#  ['big', 'data', 'benchmark', 'big', 'd'],
#  ['big', 'data', 'ownership', 'data', 'recent', 'development', 'europe'],
#  ['big', 'survey', 'big', 'data', 'centre'],
#  ['big',
#   'data',
#   'approach',
#   'trauma',
#   'outcome',
#   'prediction',
#   'autonomous',
#   'resuscitation',
#   'shiming',
#   'yang',
#   'mary',
#   'njoku',
#   'colin',
#   'f',
#   'mackenzie',
#   'discus',
#   'massive',
#   'clinical',
#   'data',
#   'used',
#   'learning',
#   'prediction',
#   'model',
#   'level',
#   'trauma',
#   'centre',
#   'support',
#   'decision',
#   'making',
#   'trauma',
#   'patient'],
#  ['big', 'data', 'becomes', 'big', 'business', 'computing', 'infrastructure'],
#  ['big',
#   'data',
#   'analysis',
#   'signal',
#   'processing',
#   'graph',
#   'representation',
#   'processing',
#   'massive',
#   'data',
#   'set',
#   'irregular',
#   'structure'],
#  ['big',
#   'data',
#   'data',
#   'science',
#   'health',
#   'care',
#   'nurse',
#   'midwife',
#   'need',
#   'know'],
#  ['big',
#   'data',
#   'big',
#   'city',
#   'graph',
#   'signal',
#   'urban',
#   'air',
#   'pollution',
#   'exploratory',
#   'sp'],
#  ['big', 'complex', 'biomedical', 'data', 'towards', 'taxonomy', 'data'],
#  ['big',
#   'data',
#   'big',
#   'knowledge',
#   'brazilian',
#   'genomics',
#   'process',
#   'academic',
#   'marketization'],
#  ['data',
#   'verification',
#   'task',
#   'scheduling',
#   'based',
#   'dynamic',
#   'resource',
#   'allocation',
#   'mobile',
#   'big',
#   'data',
#   'storage'],
#  ['big', 'data', 'security', 'understanding', 'risk'],
#  ['big',
#   'data',
#   'healthcare',
#   'life',
#   'science',
#   'learning',
#   'useful',
#   'insight',
#   'imperfect',
#   'data'],
#  ['big',
#   'data',
#   'analytics',
#   'course',
#   'given',
#   'student',
#   'expectation',
#   'industry',
#   'demand',
#   'time',
#   'frame',
#   'content',
#   'make',
#   'analytics',
#   'course',
#   'big',
#   'data',
#   'friendly'],
#  ['big',
#   'data',
#   'bigger',
#   'question',
#   'data',
#   'based',
#   'business',
#   'model',
#   'implication',
#   'organizational',
#   'boundary',
#   'data',
#   'governance',
#   'society'],
#  ['data', 'ex', 'machina', 'introduction', 'big', 'data'],
#  ['big',
#   'data',
#   'semiconductor',
#   'industry',
#   'front',
#   'lagging',
#   'behind',
#   'capital',
#   'equipment',
#   'supplier',
#   'must',
#   'provide',
#   'advanced',
#   'analytical',
#   'system',
#   'leverage',
#   'data',
#   'generated',
#   'tool',
#   'help',
#   'fab',
#   'customer',
#   'address',
#   'challenge',
#   'big',
#   'data',
#   'advanced',
#   'analytics'],
#  ['data',
#   'intensive',
#   'application',
#   'challenge',
#   'technique',
#   'technology',
#   'survey',
#   'big',
#   'data'],
#  ['big',
#   'data',
#   'management',
#   'security',
#   'application',
#   'telemetry',
#   'data',
#   'product'],
#  ['data', 'modeling', 'age', 'big', 'data'],
#  ['big',
#   'data',
#   'big',
#   'innovation',
#   'book',
#   'excerpt',
#   'enabling',
#   'competitive',
#   'differentiation',
#   'business',
#   'analytics'],
#  ['big', 'data', 'big', 'data', 'set'],
#  ['big', 'data', 'big', 'data'],
#  ['big', 'data', 'medicine', 'big', 'deal'],
#  ['big', 'data', 'big', 'concern', 'ethic', 'digital', 'age'],
#  ['big',
#   'biotech',
#   'data',
#   'implementing',
#   'large',
#   'scale',
#   'data',
#   'processing',
#   'analysis',
#   'bioprocessing'],
#  ['big',
#   'data',
#   'strategy',
#   'approach',
#   'business',
#   'driven',
#   'discovery',
#   'based'],
#  ['big',
#   'data',
#   'big',
#   'opportunity',
#   'petroleum',
#   'petrochemical',
#   'industry'],
#  ['big',
#   'data',
#   'cloud',
#   'bring',
#   'device',
#   'data',
#   'protection',
#   'law',
#   'address',
#   'impact',
#   'datafication'],
#  ['data',
#   'transfer',
#   'scheduling',
#   'maximizing',
#   'throughput',
#   'big',
#   'data',
#   'computing',
#   'cloud',
#   'system'],
#  ['big',
#   'data',
#   'second',
#   'three',
#   'article',
#   'l',
#   'amp',
#   'big',
#   'data',
#   'jonathan',
#   'kettleborough',
#   'examines',
#   'l',
#   'amp',
#   'historically',
#   'struggled',
#   'get',
#   'best',
#   'information'],
#  ['big', 'data', 'open', 'data', 'closed', 'topic'],
#  ['big',
#   'data',
#   'big',
#   'brother',
#   'china',
#   'us',
#   'social',
#   'medium',
#   'rate',
#   'citizen'],
#  ['big',
#   'tiger',
#   'big',
#   'data',
#   'learning',
#   'social',
#   'reaction',
#   'china',
#   'anticorruption',
#   'campaign',
#   'online',
#   'feedback'],
#  ['big',
#   'data',
#   'blue',
#   'fact',
#   'corporation',
#   'access',
#   'ream',
#   'data',
#   'customer',
#   'stokes',
#   'consumer',
#   'fear',
#   'company',
#   'responding',
#   'internal',
#   'control',
#   'open',
#   'privacy',
#   'policy',
#   'ethical',
#   'code',
#   'greater',
#   'candor',
#   'collecting',
#   'parsing',
#   'personal',
#   'data'],
#  ['big',
#   'data',
#   'analytics',
#   'marketing',
#   'hype',
#   'real',
#   'help',
#   'finding',
#   'valuable',
#   'consumer',
#   'insight',
#   'stream',
#   'data'],
#  ['big',
#   'data',
#   'aging',
#   'dementia',
#   'pathway',
#   'international',
#   'harmonization',
#   'data',
#   'sharing'],
#  ['big', 'data', 'data', 'science', 'critical', 'care'],
#  ['big',
#   'data',
#   'issue',
#   'international',
#   'political',
#   'sociology',
#   'data',
#   'practice'],
#  ['big',
#   'data',
#   'big',
#   'insight',
#   'investigating',
#   'language',
#   'specific',
#   'driver',
#   'hotel',
#   'satisfaction',
#   'user',
#   'generated',
#   'review'],
#  ['data', 'learning', 'big', 'data'],
#  ['big',
#   'data',
#   'predictive',
#   'analytics',
#   'manufacturing',
#   'performance',
#   'integrating',
#   'institutional',
#   'theory',
#   'resource',
#   'based',
#   'view',
#   'big',
#   'data',
#   'culture'],
#  ['data',
#   'science',
#   'prediction',
#   'big',
#   'data',
#   'promise',
#   'automated',
#   'actionable',
#   'knowledge',
#   'creation',
#   'predictive',
#   'model',
#   'use',
#   'human',
#   'computer'],
#  ['data',
#   'data',
#   'everywhere',
#   'big',
#   'data',
#   'myth',
#   'marketing',
#   'device',
#   'various',
#   'stakeholder',
#   'public',
#   'private',
#   'sector',
#   'discus',
#   'concept',
#   'positive',
#   'negative'],
#  ['data', 'data', 'big', 'data'],
#  ['big',
#   'data',
#   'trend',
#   'stroke',
#   'epidemiology',
#   'united',
#   'state',
#   'good',
#   'data'],
#  ['data',
#   'prefetching',
#   'eviction',
#   'mechanism',
#   'memory',
#   'storage',
#   'system',
#   'based',
#   'scheduling',
#   'big',
#   'data',
#   'processing'],
#  ['big', 'result', 'big', 'data'],
#  ['data',
#   'mining',
#   'based',
#   'big',
#   'data',
#   'analytics',
#   'parameter',
#   'layered',
#   'framework'],
#  ['big', 'data', 'big', 'pain', 'big', 'gain', 'lawyer'],
#  ['big', 'data', 'progress', 'big', 'headache'],
#  ['big',
#   'data',
#   'real',
#   'time',
#   'fact',
#   'based',
#   'decision',
#   'next',
#   'big',
#   'thing',
#   'supply',
#   'chain'],
#  ['big',
#   'data',
#   'buzzword',
#   'du',
#   'jour',
#   'c',
#   'academic',
#   'best',
#   'job',
#   'michael',
#   'stonebraker',
#   'analyzes',
#   'different',
#   'variety',
#   'big',
#   'data',
#   'judy',
#   'robertson',
#   'considers',
#   'reward',
#   'teaching',
#   'computer',
#   'science'],
#  ['big',
#   'data',
#   'analytics',
#   'mining',
#   'effective',
#   'visualization',
#   'trend',
#   'forecasting',
#   'crime',
#   'data'],
#  ['big',
#   'data',
#   'telecommunication',
#   'operator',
#   'data',
#   'platform',
#   'practice'],
#  ['big', 'data', 'big', 'deal'],
#  ['big',
#   'sensing',
#   'data',
#   'curation',
#   'cloud',
#   'coming',
#   'promise',
#   'scalable',
#   'cloud',
#   'data',
#   'center',
#   'mitigation',
#   'next',
#   'generation',
#   'iot',
#   'wireless',
#   'sensor',
#   'network'],
#  ['big',
#   'data',
#   'internal',
#   'audit',
#   'liz',
#   'sandwith',
#   'chartered',
#   'institute',
#   'internal',
#   'auditor',
#   'look',
#   'big',
#   'data',
#   'affect',
#   'internal',
#   'audit',
#   'process'],
#  ['big',
#   'data',
#   'security',
#   'policy',
#   'towards',
#   'framework',
#   'regulating',
#   'phase',
#   'analytics',
#   'use',
#   'big',
#   'data'],
#  ['big',
#   'data',
#   'current',
#   'campaign',
#   'concerning',
#   'big',
#   'data',
#   'pipe',
#   'dream',
#   'unleash',
#   'huge',
#   'gain',
#   'turbine',
#   'design',
#   'operation',
#   'maintenance',
#   'reliability'],
#  ['big',
#   'data',
#   'savvy',
#   'team',
#   'skill',
#   'big',
#   'data',
#   'driven',
#   'action',
#   'business',
#   'performance'],
#  ['big',
#   'data',
#   'big',
#   'legal',
#   'research',
#   'question',
#   'legal',
#   'analytics',
#   'database',
#   'allow',
#   'reference',
#   'law',
#   'librarian',
#   'meet',
#   'increasing',
#   'demand',
#   'comprehensive',
#   'information',
#   'efficient',
#   'rate'],
#  ['big',
#   'data',
#   'solar',
#   'power',
#   'forecasting',
#   'based',
#   'deep',
#   'learning',
#   'multiple',
#   'data',
#   'source'],
#  ['big',
#   'data',
#   'utility',
#   'social',
#   'work',
#   'learning',
#   'big',
#   'data',
#   'revolution',
#   'business',
#   'healthcare'],
#  ['big',
#   'data',
#   'radiation',
#   'biology',
#   'epidemiology',
#   'overview',
#   'historical',
#   'contemporary',
#   'landscape',
#   'data',
#   'biomaterial',
#   'archive'],
#  ['big',
#   'data',
#   'big',
#   'problem',
#   'precision',
#   'medicine',
#   'stroke',
#   'neurocritical',
#   'care'],
#  ['big', 'data', 'big', 'storage'],
#  ['big',
#   'data',
#   'analytics',
#   'big',
#   'financial',
#   'institution',
#   'big',
#   'money',
#   'fraud',
#   'litigation'],
#  ['big', 'data', 'fourth', 'data', 'management', 'generation'],
#  ['data', 'dogma', 'big', 'data', 'open', 'data', 'opportunity', 'ahead'],
#  ['big',
#   'data',
#   'device',
#   'reprocessing',
#   'among',
#   'fda',
#   'device',
#   'science',
#   'goal',
#   'fda',
#   'device',
#   'center',
#   'science',
#   'council',
#   'want',
#   'leverage',
#   'called',
#   'big',
#   'data',
#   'evidence',
#   'real',
#   'world',
#   'clinical',
#   'experience',
#   'improve',
#   'reprocessing',
#   'reusable',
#   'medical',
#   'device',
#   'enhance',
#   'use',
#   'health',
#   'information',
#   'technology',
#   'device',
#   'cybersecurity',
#   'among',
#   'fy',
#   'regulatory',
#   'science',
#   'goal'],
#  ['big', 'data', 'magic', 'data'],
#  ['big',
#   'data',
#   'talent',
#   'management',
#   'using',
#   'hard',
#   'data',
#   'make',
#   'soft',
#   'stuff',
#   'easy'],
#  ['big',
#   'data',
#   'approach',
#   'phenotyping',
#   'acute',
#   'ischemic',
#   'stroke',
#   'using',
#   'automated',
#   'lesion',
#   'segmentation',
#   'multi',
#   'center',
#   'magnetic',
#   'resonance',
#   'imaging',
#   'data'],
#  ['data',
#   'driven',
#   'stochastic',
#   'robust',
#   'optimization',
#   'general',
#   'computational',
#   'framework',
#   'algorithm',
#   'leveraging',
#   'machine',
#   'learning',
#   'optimization',
#   'uncertainty',
#   'big',
#   'data',
#   'era'],
#  ['big',
#   'data',
#   'biggest',
#   'shake',
#   'data',
#   'law',
#   'two',
#   'decade',
#   'general',
#   'data',
#   'protection',
#   'regulation',
#   'four',
#   'month',
#   'away',
#   'already',
#   'need',
#   'getting',
#   'head',
#   'round'],
#  ['big',
#   'data',
#   'big',
#   'question',
#   'surrounding',
#   'vesicoureteral',
#   'reflux',
#   'management'],
#  ['big', 'data', 'big', 'number'],
#  ['big',
#   'data',
#   'processing',
#   'minimal',
#   'delay',
#   'guaranteed',
#   'data',
#   'resolution',
#   'disaster',
#   'area'],
#  ['big',
#   'data',
#   'based',
#   'improved',
#   'data',
#   'acquisition',
#   'storage',
#   'system',
#   'designing',
#   'industrial',
#   'data',
#   'platform'],
#  ['data',
#   'science',
#   'predictive',
#   'analytics',
#   'big',
#   'data',
#   'supply',
#   'chain',
#   'management',
#   'current',
#   'state',
#   'future',
#   'potential'],
#  ['data',
#   'driven',
#   'mary',
#   'hammon',
#   'explains',
#   'leverage',
#   'potential',
#   'big',
#   'data',
#   'planning',
#   'practice'],
#  ['data', 'mining', 'unstructured', 'big', 'data', 'cloud', 'computing'],
#  ['data',
#   'warehousing',
#   'olap',
#   'big',
#   'data',
#   'survey',
#   'state',
#   'art',
#   'open',
#   'problem',
#   'future',
#   'challenge'],
#  ['big',
#   'data',
#   'quality',
#   'assurance',
#   'data',
#   'traceability',
#   'case',
#   'study',
#   'national',
#   'standard',
#   'reference',
#   'data',
#   'program',
#   'korea'],
#  ['big', 'data', 'big', 'problem', 'causation', 'confounders', 'cohort'],
#  ['big',
#   'data',
#   'making',
#   'better',
#   'use',
#   'data',
#   'offer',
#   'numerous',
#   'way',
#   'add',
#   'value',
#   'company',
#   'activity'],
#  ['data', 'danger', 'big', 'data', 'sight', 'eu', 'regulator'],
#  ['big', 'data', 'big', 'deal'],
#  ['big',
#   'data',
#   'analytics',
#   'sentiment',
#   'u',
#   'china',
#   'reaction',
#   'data',
#   'collection',
#   'business',
#   'government'],
#  ['big',
#   'data',
#   'first',
#   'three',
#   'article',
#   'big',
#   'data',
#   'jonathan',
#   'kettleborough',
#   'provides',
#   'introduction',
#   'bd',
#   'role',
#   'within',
#   'l',
#   'amp'],
#  ['big',
#   'data',
#   'driven',
#   'lithium',
#   'ion',
#   'battery',
#   'modeling',
#   'method',
#   'based',
#   'sdae',
#   'elm',
#   'algorithm',
#   'data',
#   'pre',
#   'processing',
#   'technology'],
#  ['big',
#   'data',
#   'multiple',
#   'sclerosis',
#   'development',
#   'web',
#   'based',
#   'longitudinal',
#   'study',
#   'viewer',
#   'imaging',
# ...
#  ['time',
#   'series',
#   'data',
#   'mining',
#   'case',
#   'study',
#   'big',
#   'data',
#   'analytics',
#   'approach'],
#  ['highly',
#   'efficient',
#   'data',
#   'migration',
#   'backup',
#   'big',
#   'data',
#   'application',
#   'elastic',
#   'optical',
#   'inter',
#   'data',
#   'center',
#   'network'],
#  ['hugo', 'rifkind', 'big', 'money', 'big', 'data'],
#  ['nosql',
#   'based',
#   'spatial',
#   'data',
#   'processing',
#   'system',
#   'big',
#   'data',
#   'environment'],
#  ['disaggregating', 'asthma', 'big', 'investigation', 'versus', 'big', 'data'],
#  ['biobanking', 'big', 'data', 'need', 'developing', 'big', 'data', 'metric'],
#  ['online', 'spotlight', 'big', 'data', 'big'],
#  ['impact',
#   'big',
#   'data',
#   'analytics',
#   'individual',
#   'south',
#   'korean',
#   'big',
#   'data',
#   'analytics',
#   'market'],
#  ['taking',
#   'big',
#   'data',
#   'approach',
#   'data',
#   'quality',
#   'citizen',
#   'science',
#   'project'],
#  ['kinematics',
#   'big',
#   'biomedical',
#   'data',
#   'characterize',
#   'temporal',
#   'variability',
#   'seasonality',
#   'data',
#   'repository',
#   'functional',
#   'data',
#   'analysis',
#   'data',
#   'temporal',
#   'evolution',
#   'non',
#   'parametric',
#   'statistical',
#   'manifold'],
#  ['variable',
#   'diet',
#   'variable',
#   'data',
#   'printing',
#   'touted',
#   'tomorrow',
#   'next',
#   'big',
#   'thing',
#   'company',
#   'like',
#   'idg',
#   'variable',
#   'data',
#   'printing',
#   'everyday',
#   'reality'],
#  ['nursing',
#   'management',
#   'minimum',
#   'data',
#   'set',
#   'cost',
#   'effective',
#   'tool',
#   'demonstrate',
#   'value',
#   'nurse',
#   'staffing',
#   'big',
#   'data',
#   'science',
#   'era'],
#  ['managing',
#   'technology',
#   'big',
#   'data',
#   'come',
#   'big',
#   'responsibility',
#   'allowing',
#   'people',
#   'control',
#   'data',
#   'may',
#   'actually',
#   'benefit',
#   'company',
#   'long',
#   'run',
#   'mit',
#   'medium',
#   'lab',
#   'alex',
#   'sandy',
#   'pentland'],
#  ['application',
#   'big',
#   'data',
#   'technology',
#   'field',
#   'combat',
#   'simulation',
#   'data',
#   'management'],
#  ['seth',
#   'stephen',
#   'davidowitz',
#   'everybody',
#   'lie',
#   'big',
#   'data',
#   'new',
#   'data',
#   'internet',
#   'tell',
#   'u',
#   'really'],
#  ['modeling',
#   'optimization',
#   'big',
#   'data',
#   'analytics',
#   'statistical',
#   'learning',
#   'tool',
#   'era',
#   'data',
#   'deluge'],
#  ['northern',
#   'telecom',
#   'big',
#   'plan',
#   'data',
#   'networking',
#   'new',
#   'division',
#   'enterprise',
#   'data',
#   'network'],
#  ['predicting',
#   'flu',
#   'rate',
#   'using',
#   'big',
#   'data',
#   'analytics',
#   'based',
#   'social',
#   'data',
#   'weather',
#   'condition'],
#  ['analysis', 'medical', 'data', 'using', 'big', 'data', 'r'],
#  ['analyze', 'big', 'demand', 'big', 'data', 'professional'],
#  ['cloud',
#   'based',
#   'energy',
#   'data',
#   'mining',
#   'information',
#   'agent',
#   'system',
#   'based',
#   'big',
#   'data',
#   'analysis',
#   'technology'],
#  ['universal',
#   'health',
#   'coverage',
#   'x',
#   'big',
#   'thinking',
#   'versus',
#   'big',
#   'data'],
#  ['regulatory',
#   'watch',
#   'big',
#   'data',
#   'smart',
#   'data',
#   'fda',
#   'informed',
#   'initiative'],
#  ['convex',
#   'optimization',
#   'big',
#   'data',
#   'scalable',
#   'randomized',
#   'parallel',
#   'algorithm',
#   'big',
#   'data',
#   'analytics'],
#  ['improving',
#   'performance',
#   'data',
#   'mining',
#   'using',
#   'big',
#   'data',
#   'cloud',
#   'environment'],
#  ['state',
#   'society',
#   'relationship',
#   'big',
#   'data',
#   'big',
#   'future',
#   'editorial'],
#  ['extracting',
#   'value',
#   'data',
#   'analytic',
#   'social',
#   'network',
#   'big',
#   'data',
#   'approach'],
#  ['critique',
#   'imbalanced',
#   'data',
#   'learning',
#   'approach',
#   'big',
#   'data',
#   'analytics'],
#  ['opening',
#   'big',
#   'data',
#   'computer',
#   'assisted',
#   'analysis',
#   'textual',
#   'data',
#   'social',
#   'science'],
#  ['towards',
#   'building',
#   'data',
#   'intensive',
#   'index',
#   'big',
#   'data',
#   'computing',
#   'case',
#   'study',
#   'remote',
#   'sensing',
#   'data',
#   'processing'],
#  ['uncharted',
#   'territory',
#   'big',
#   'learning',
#   'data',
#   'applying',
#   'big',
#   'data',
#   'training',
#   'development',
#   'field',
#   'method',
#   'soon',
#   'make',
#   'mark',
#   'industry'],
#  ['cloud',
#   'parallel',
#   'spatial',
#   'temporal',
#   'data',
#   'model',
#   'intelligent',
#   'parameter',
#   'adaptation',
#   'spatial',
#   'temporal',
#   'big',
#   'data'],
#  ['political',
#   'science',
#   'big',
#   'data',
#   'structured',
#   'data',
#   'unstructured',
#   'data',
#   'use'],
#  ['role', 'big', 'data', 'real', 'world', 'data'],
#  ['technology',
#   'getting',
#   'smart',
#   'big',
#   'data',
#   'smaller',
#   'company',
#   'becoming',
#   'increasingly',
#   'sophisticated',
#   'analyzing',
#   'multiple',
#   'form',
#   'data'],
#  ['expanding', 'mind', 'big', 'data', 'data', 'science'],
#  ['research',
#   'network',
#   'data',
#   'mining',
#   'based',
#   'reliability',
#   'source',
#   'big',
#   'data',
#   'environment'],
#  ['machine',
#   'learning',
#   'big',
#   'data',
#   'analytics',
#   'bipolar',
#   'disorder',
#   'position',
#   'paper',
#   'international',
#   'society',
#   'bipolar',
#   'disorder',
#   'big',
#   'data',
#   'task',
#   'force'],
#  ['click',
#   'data',
#   'scientist',
#   'big',
#   'data',
#   'predictive',
#   'analytics',
#   'theory',
#   'development',
#   'era',
#   'maker',
#   'movement',
#   'supply',
#   'chain'],
#  ['conference',
#   'report',
#   'health',
#   'data',
#   'protection',
#   'law',
#   'era',
#   'big',
#   'data',
#   'risk',
#   'opportunity',
#   'modernization'],
#  ['experiment',
#   'big',
#   'data',
#   'storage',
#   'querying',
#   'visualisation',
#   'data',
#   'taken',
#   'liverpool',
#   'telescope',
#   'wide',
#   'field',
#   'camera'],
#  ['layered',
#   'software',
#   'pattern',
#   'data',
#   'analysis',
#   'big',
#   'data',
#   'environment'],
#  ['gpu',
#   'daemon',
#   'gpu',
#   'algorithm',
#   'design',
#   'data',
#   'management',
#   'optimization',
#   'template',
#   'array',
#   'based',
#   'big',
#   'omics',
#   'data'],
#  ['u',
#   'government',
#   'bet',
#   'big',
#   'data',
#   'multi',
#   'agency',
#   'big',
#   'data',
#   'initiative',
#   'offer',
#   'array',
#   'national',
#   'advantage'],
#  ['tuning',
#   'small',
#   'analytics',
#   'big',
#   'data',
#   'data',
#   'partitioning',
#   'secondary',
#   'index',
#   'hadoop',
#   'ecosystem'],
#  ['opportunity',
#   'challenge',
#   'big',
#   'data',
#   'social',
#   'science',
#   'case',
#   'genomic',
#   'data'],
#  ['author',
#   'response',
#   'gong',
#   'comment',
#   'data',
#   'science',
#   'relationship',
#   'big',
#   'data',
#   'data',
#   'driven',
#   'decision',
#   'making'],
#  ['big', 'data', 'big', 'deal'],
#  ['big',
#   'data',
#   'guide',
#   'understanding',
#   'climate',
#   'change',
#   'case',
#   'theory',
#   'guided',
#   'data',
#   'science'],
#  ['correction',
#   'predictive',
#   'modeling',
#   'big',
#   'data',
#   'bigger',
#   'really',
#   'better',
#   'junqu',
#   'de',
#   'fortuny',
#   'e',
#   'marten',
#   'provost',
#   'f',
#   'big',
#   'data'],
#  ['big',
#   'boe',
#   'fusing',
#   'spanish',
#   'official',
#   'gazette',
#   'big',
#   'data',
#   'technology'],
#  ['data',
#   'science',
#   'relationship',
#   'big',
#   'data',
#   'data',
#   'driven',
#   'decision',
#   'making'],
#  ['thermal',
#   'aware',
#   'dvfs',
#   'enabled',
#   'big',
#   'data',
#   'task',
#   'scheduling',
#   'data',
#   'center'],
#  ['reference',
#   'architecture',
#   'big',
#   'data',
#   'solution',
#   'introducing',
#   'model',
#   'perform',
#   'predictive',
#   'analytics',
#   'using',
#   'big',
#   'data',
#   'technology'],
#  ['resting',
#   'state',
#   'fmri',
#   'functional',
#   'connectivity',
#   'big',
#   'data',
#   'preprocessing',
#   'pipeline',
#   'topological',
#   'data',
#   'analysis'],
#  ['sport',
#   'analytics',
#   'era',
#   'big',
#   'data',
#   'moving',
#   'toward',
#   'next',
#   'frontier'],
#  ['big',
#   'data',
#   'analysis',
#   'swimming',
#   'pool',
#   'impact',
#   'household',
#   'electric',
#   'intensity',
#   'san',
#   'antonio',
#   'texas'],
#  ['big', 'data', 'lost', 'cloud'],
#  ['big',
#   'earth',
#   'data',
#   'comprehensive',
#   'analysis',
#   'visualization',
#   'analytics',
#   'issue'],
#  ['tv', 'audience', 'measurement', 'big', 'data'],
#  ['big',
#   'data',
#   'efficient',
#   'market',
#   'end',
#   'daily',
#   'fantasy',
#   'sport',
#   'know'],
#  ['call',
#   'paper',
#   'special',
#   'issue',
#   'computational',
#   'propaganda',
#   'political',
#   'big',
#   'data'],
#  ['diversity', 'big', 'data', 'review'],
#  ['big', 'data', 'rise', 'machine', 'financial', 'market'],
#  ['big', 'data', 'machine', 'analyze', 'stock', 'market', 'sentiment'],
#  ['recent', 'advance', 'earth', 'observation', 'big', 'data', 'hydrology'],
#  ['big', 'data', 'healthcare', 'opportunity', 'challenge'],
#  ['medical',
#   'school',
#   'training',
#   'relate',
#   'practice',
#   'evidence',
#   'big',
#   'data'],
#  ['u',
#   'army',
#   'person',
#   'event',
#   'data',
#   'environment',
#   'military',
#   'civilian',
#   'big',
#   'data',
#   'enterprise'],
#  ['big', 'data', 'social', 'good'],
#  ['structural', 'consequence', 'big', 'data', 'driven', 'education'],
#  ['big',
#   'data',
#   'based',
#   'security',
#   'analytics',
#   'protecting',
#   'virtualized',
#   'infrastructure',
#   'cloud',
#   'computing'],
#  ['big', 'earth', 'data', 'analytics', 'survey'],
#  ['research', 'dilemma', 'behavioral', 'big', 'data'],
#  ['bring', 'big', 'data', 'beyond', 'hype'],
#  ['global',
#   'water',
#   'cycle',
#   'remote',
#   'sensing',
#   'big',
#   'data',
#   'overview',
#   'challenge',
#   'opportunity'],
#  ['big', 'data', 'predictive', 'analytics', 'health', 'care'],
#  ['big',
#   'earth',
#   'data',
#   'new',
#   'frontier',
#   'earth',
#   'information',
#   'science'],
#  ['combining',
#   'human',
#   'computing',
#   'machine',
#   'learning',
#   'make',
#   'sense',
#   'big',
#   'aerial',
#   'data',
#   'disaster',
#   'response'],
#  ['scientific',
#   'training',
#   'era',
#   'big',
#   'data',
#   'new',
#   'pedagogy',
#   'graduate',
#   'education'],
#  ['big',
#   'earth',
#   'data',
#   'analytics',
#   'sentinel',
#   'landsat',
#   'imagery',
#   'support',
#   'global',
#   'human',
#   'settlement',
#   'mapping'],
#  ['role',
#   'teamwork',
#   'analysis',
#   'big',
#   'data',
#   'study',
#   'visual',
#   'analytics',
#   'box',
#   'office',
#   'prediction'],
#  ['big', 'data', 'drive', 'development', 'earth', 'science'],
#  ['view',
#   'based',
#   'model',
#   'data',
#   'cube',
#   'support',
#   'big',
#   'earth',
#   'data',
#   'system',
#   'interoperability'],
#  ['challenge', 'big', 'data', 'earth'],
#  ['big', 'spatial', 'vector', 'data', 'management', 'review'],
#  ['exploiting',
#   'big',
#   'earth',
#   'data',
#   'space',
#   'first',
#   'experience',
#   'timescan',
#   'processing',
#   'chain'],
#  ['call', 'paper', 'special', 'issue', 'big', 'data', 'robotics'],
#  ['multiple',
#   'target',
#   'tracking',
#   'big',
#   'data',
#   'based',
#   'measurement',
#   'extended',
#   'binary',
#   'phase',
#   'shift',
#   'keying',
#   'transceiver'],
#  ['new',
#   'big',
#   'data',
#   'approach',
#   'based',
#   'geoecological',
#   'information',
#   'modeling',
#   'system'],
#  ['gsio',
#   'programmatic',
#   'interface',
#   'delivering',
#   'big',
#   'earth',
#   'data',
#   'service'],
#  ['comparative',
#   'study',
#   'big',
#   'data',
#   'global',
#   'adakites',
#   'mineralization',
#   'related',
#   'granite',
#   'geza',
#   'arc',
#   'metallogenic',
#   'belt',
#   'northwest',
#   'yunnan',
#   'southwest',
#   'china'],
#  ['big', 'data', 'cataclysm', 'catalyst'],
#  ['message', 'editor', 'chief', 'big', 'data'],
#  ['curating',
#   'big',
#   'data',
#   'made',
#   'simple',
#   'perspective',
#   'scientific',
#   'community'],
#  ['computational',
#   'propaganda',
#   'political',
#   'big',
#   'data',
#   'moving',
#   'toward',
#   'critical',
#   'research',
#   'agenda'],
#  ['efficient',
#   'utilization',
#   'multi',
#   'core',
#   'processor',
#   'many',
#   'core',
#   'co',
#   'processor',
#   'supercomputer',
#   'beacon',
#   'scalable',
#   'geocomputation',
#   'geo',
#   'simulation',
#   'big',
#   'earth',
#   'data'],
#  ['us', 'big', 'data', 'city'],
#  ['big',
#   'data',
#   'new',
#   'method',
#   'idea',
#   'geological',
#   'scientific',
#   'research'],
#  ['new',
#   'discrimination',
#   'diagram',
#   'basalt',
#   'based',
#   'big',
#   'data',
#   'research'],
#  ['semantics',
#   'way',
#   'semantic',
#   'web',
#   'open',
#   'science',
#   'big',
#   'earth',
#   'data'],
#  ['national',
#   'survey',
#   'population',
#   'health',
#   'big',
#   'data',
#   'analytics',
#   'mobile',
#   'health',
#   'monitor'],
#  ['big',
#   'data',
#   'little',
#   'data',
#   'care',
#   'coordination',
#   'medicare',
#   'beneficiary',
#   'medigap',
#   'coverage'],
#  ['call',
#   'paper',
#   'special',
#   'issue',
#   'computational',
#   'propaganda',
#   'political',
#   'big',
#   'data'],
#  ['big', 'scholarly', 'data', 'survey'],
#  ['call', 'special', 'issue', 'paper', 'big', 'data', 'business'],
#  ['data', 'behaviour', 'model', 'big', 'data', 'visual', 'analytics'],
#  ['geospatial',
#   'semantics',
#   'ontology',
#   'knowledge',
#   'graph',
#   'big',
#   'earth',
#   'data'],
#  ['big',
#   'uncertain',
#   'data',
#   'multiple',
#   'sensor',
#   'efficient',
#   'processing',
#   'high',
#   'order',
#   'multi',
#   'hypothesis',
#   'evidence',
#   'theoretic',
#   'approach'],
#  ['big', 'data', 'robotics'],
#  ['optimizing', 'sentinel', 'image', 'selection', 'big', 'data', 'context'],
#  ['unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner'],
#  ['big', 'data', 'lost', 'cloud'],
#  ['big', 'data', 'enabler', 'primary', 'education'],
#  ['generalized',
#   'supervised',
#   'classification',
#   'scheme',
#   'produce',
#   'provincial',
#   'wetland',
#   'inventory',
#   'map',
#   'application',
#   'google',
#   'earth',
#   'engine',
#   'big',
#   'geo',
#   'data',
#   'processing'],
#  ['common', 'big', 'data', 'challenge', 'overcome'],
#  ['big',
#   'data',
#   'ensemble',
#   'clinical',
#   'prediction',
#   'healthcare',
#   'data',
#   'using',
#   'deep',
#   'learning',
#   'model'],
#  ['correction', 'big', 'data'],
#  ['scalable',
#   'data',
#   'quality',
#   'big',
#   'data',
#   'pythia',
#   'framework',
#   'handling',
#   'missing',
#   'value'],
#  ['soom', 'sort', 'based', 'optimizer', 'big', 'data', 'multi', 'query'],
#  ['deep', 'learning', 'big', 'sparse', 'behavioral', 'data'],
#  ['call', 'special', 'issue', 'paper', 'big', 'data', 'business'],
#  ['exercise',
#   'exploring',
#   'big',
#   'data',
#   'producing',
#   'reliable',
#   'statistical',
#   'information'],
#  ['big', 'data', 'literature', 'search'],
#  ['using',
#   'big',
#   'data',
#   'understand',
#   'human',
#   'condition',
#   'kavli',
#   'human',
#   'project'],
#  ['call', 'paper', 'special', 'issue', 'big', 'data', 'robotics'],
#  ['strength',
#   'number',
#   'using',
#   'big',
#   'data',
#   'simplify',
#   'sentiment',
#   'classification'],
#  ['labor',
#   'economist',
#   'get',
#   'microscope',
#   'big',
#   'data',
#   'labor',
#   'market',
#   'analysis'],
#  ['furthest',
#   'pair',
#   'based',
#   'binary',
#   'search',
#   'tree',
#   'speeding',
#   'big',
#   'data',
#   'classification',
#   'using',
#   'k',
#   'nearest',
#   'neighbor'],
#  ['interview',
#   'dr',
#   'silvio',
#   'carta',
#   'author',
#   'book',
#   'big',
#   'data',
#   'code',
#   'discrete',
#   'city',
#   'routledge'],
#  ['clustering', 'big', 'spatiotemporal', 'interval', 'data'],
#  ['agile',
#   'big',
#   'data',
#   'analytics',
#   'web',
#   'based',
#   'system',
#   'architecture',
#   'centric',
#   'approach'],
#  ['big',
#   'data',
#   'analytics',
#   'framework',
#   'border',
#   'crossing',
#   'transportation'],
#  ['analyzing',
#   'big',
#   'smart',
#   'metering',
#   'data',
#   'towards',
#   'differentiated',
#   'user',
#   'service',
#   'sublinear',
#   'approach'],
#  ['big',
#   'data',
#   'based',
#   'rf',
#   'localisation',
#   'method',
#   'unmanned',
#   'search',
#   'rescue'],
#  ['intelligent', 'big', 'data', 'analysis', 'review'],
#  ['health',
#   'big',
#   'data',
#   'analytics',
#   'current',
#   'perspective',
#   'challenge',
#   'potential',
#   'solution'],
#  ['intelligent', 'big', 'data', 'analysis', 'review'],
#  ['health',
#   'big',
#   'data',
#   'analytics',
#   'current',
#   'perspective',
#   'challenge',
#   'potential',
#   'solution'],
#  ['guest', 'editorial', 'big', 'data', 'analytics', 'web'],
#  ['guest', 'editorial', 'big', 'data', 'infrastructure'],
#  ['guest',
#   'editorial',
#   'big',
#   'medium',
#   'data',
#   'understanding',
#   'search',
#   'mining'],
#  ['guest',
#   'editorial',
#   'big',
#   'scholar',
#   'data',
#   'discovery',
#   'collaboration'],
#  ['guest',
#   'editorial',
#   'big',
#   'medium',
#   'data',
#   'understanding',
#   'search',
#   'mining'],
#  ['speed',
#   'big',
#   'data',
#   'analytics',
#   'unveiling',
#   'storage',
#   'distribution',
#   'sub',
#   'datasets'],
#  ['architecting', 'time', 'critical', 'big', 'data', 'system']]

# %%
# 하나의 리스트로 병합
words2 = list(reduce(lambda x, y: x+y,words))
words2  #작업 내용 확인
# Out:
# ['guest',
#  'editorial',
#  'big',
#  'medium',
#  'data',
#  'understanding',
#  'search',
#  'mining',
#  'part',
#  'guest',
#  'editorial',
#  'big',
#  'scholar',
#  'data',
#  'discovery',
#  'collaboration',
#  'guest',
#  'editorial',
#  'big',
#  'data',
#  'analytics',
#  'web',
#  'parallel',
#  'computing',
#  'preserving',
#  'privacy',
#  'using',
#  'k',
#  'anonymisation',
#  'algorithm',
#  'big',
#  'data',
#  'nosql',
#  'database',
#  'big',
#  'data',
#  'computation',
#  'migration',
#  'new',
#  'approach',
#  'execute',
#  'big',
#  'data',
#  'bioinformatics',
#  'workflow',
#  'towards',
#  'real',
#  'time',
#  'big',
#  'data',
#  'analytics',
#  'platform',
#  'health',
#  'application',
#  'new',
#  'approach',
#  'accurate',
#  'distributed',
#  'cluster',
#  'analysis',
#  'big',
#  'data',
#  'competitive',
#  'k',
#  'mean',
#  'five',
#  'layer',
#  'architecture',
#  'big',
#  'data',
#  'processing',
#  'analytics',
#  'towards',
#  'max',
#  'min',
#  'fair',
#  'resource',
#  'allocation',
#  'stream',
#  'big',
#  'data',
#  'analytics',
#  'shared',
#  'cloud',
#  'large',
#  'scale',
#  'spectral',
#  'clustering',
#  'managing',
#  'big',
#  'data',
#  'healthcare',
#  'operation',
#  'hierarchical',
#  'distributed',
#  'processing',
#  'framework',
#  'big',
#  'image',
#  'data',
#  'platform',
#  'big',
#  'data',
#  'analytics',
#  'distributed',
#  'scale',
#  'storage',
#  'system',
#  'online',
#  'similarity',
#  'learning',
#  'big',
#  'data',
#  'overfitting',
#  'towards',
#  'quality',
#  'service',
#  'driven',
#  'consistency',
#  'big',
#  'data',
#  'management',
#  'platform',
#  'big',
#  'data',
#  'analytics',
#  'distributed',
#  'scale',
#  'storage',
#  'system',
#  'current',
#  'trend',
#  'predictive',
#  'analytics',
#  'big',
#  'data',
#  'classification',
#  'comparison',
#  'nosql',
#  'big',
#  'data',
#  'model',
#  'survey',
#  'big',
#  'data',
#  'processing',
#  'infrastructure',
#  'evolving',
#  'role',
#  'fpga',
#  'fast',
#  'approach',
#  'semantic',
#  'service',
#  'composition',
#  'big',
#  'data',
#  'environment',
#  'secure',
#  'multi',
#  'owner',
#  'based',
#  'cloud',
#  'computing',
#  'scheme',
#  'big',
#  'data',
#  'corporate',
#  'governance',
#  'fraud',
#  'detection',
#  'annual',
#  'report',
#  'using',
#  'big',
#  'data',
#  'analytics',
#  'fuzzy',
#  'based',
#  'scalable',
#  'clustering',
#  'algorithm',
#  'handling',
#  'big',
#  'data',
#  'using',
#  'apache',
#  'spark',
#  'privacy',
#  'model',
#  'big',
#  'data',
#  'survey',
#  'towards',
#  'quality',
#  'service',
#  'driven',
#  'consistency',
#  'big',
#  'data',
#  'management',
#  'new',
#  'approach',
#  'accurate',
#  'distributed',
#  'cluster',
#  'analysis',
#  'big',
#  'data',
#  'competitive',
#  'k',
#  'mean',
#  'palopro',
#  'platform',
#  'knowledge',
#  'extraction',
#  'big',
#  'social',
#  'data',
#  'news',
#  'index',
#  'ieee',
#  'transaction',
#  'big',
#  'data',
#  'vol',
#  'hybridisation',
#  'classifier',
#  'anomaly',
#  'detection',
#  'big',
#  'data',
#  'toward',
#  'efficient',
#  'flexible',
#  'metadata',
#  'indexing',
#  'big',
#  'data',
#  'system',
#  'structural',
#  'balance',
#  'theory',
#  'based',
#  'e',
#  'commerce',
#  'recommendation',
#  'big',
#  'rating',
#  'data',
#  'petuum',
#  'new',
#  'platform',
#  'distributed',
#  'machine',
#  'learning',
#  'big',
#  'data',
#  'special',
#  'issue',
#  'biomedical',
#  'big',
#  'data',
#  'understanding',
#  'learning',
#  'application',
#  'smart',
#  'monitoring',
#  'camera',
#  'driven',
#  'intelligent',
#  'processing',
#  'big',
#  'surveillance',
#  'video',
#  'data',
#  'distributed',
#  'feature',
#  'selection',
#  'efficient',
#  'economic',
#  'big',
#  'data',
#  'analysis',
#  'extended',
#  'spatio',
#  'temporal',
#  'granger',
#  'causality',
#  'model',
#  'air',
#  'quality',
#  'estimation',
#  'heterogeneous',
#  'urban',
#  'big',
#  'data',
#  'hdm',
#  'composable',
#  'framework',
#  'big',
#  'data',
#  'processing',
#  'index',
#  'ieee',
#  'transaction',
#  'big',
#  'data',
#  'vol',
#  'enhanced',
#  'visualization',
#  'method',
#  'aid',
#  'behavioral',
#  'trajectory',
#  'pattern',
#  'recognition',
#  'infrastructure',
#  'big',
#  'longitudinal',
#  'data',
#  'dip',
#  'svm',
#  'distribution',
#  'preserving',
#  'kernel',
#  'support',
#  'vector',
#  'machine',
#  'big',
#  'data',
#  'availability',
#  'modelling',
#  'assurance',
#  'big',
#  'data',
#  'computing',
#  'deduplication',
#  'encrypted',
#  'big',
#  'data',
#  'cloud',
#  'guest',
#  'editorial',
#  'special',
#  'issue',
#  'big',
#  'scholar',
#  'data',
#  'discovery',
#  'collaboration',
#  'continued',
#  'kvasir',
#  'scalable',
#  'provision',
#  'semantically',
#  'relevant',
#  'web',
#  'content',
#  'big',
#  'data',
#  'framework',
#  'perception',
#  'independent',
#  'financial',
#  'advisor',
#  'usefulness',
#  'big',
#  'data',
#  'context',
#  'decision',
#  'making',
#  'uk',
#  'optimized',
#  'deep',
#  'learning',
#  'eeg',
#  'big',
#  'data',
#  'seizure',
#  'prediction',
#  'bci',
#  'via',
#  'internet',
#  'thing',
#  'algorithmseer',
#  'system',
#  'extracting',
#  'searching',
#  'algorithm',
#  'scholarly',
#  'big',
#  'data',
#  'taxi',
#  'passenger',
#  'demand',
#  'modeling',
#  'based',
#  'big',
#  'data',
#  'roving',
#  'sensor',
#  'network',
#  'big',
#  'data',
#  'analytics',
#  'security',
#  'criminal',
#  'investigation',
#  'data',
#  'discretization',
#  'taxonomy',
#  'big',
#  'data',
#  'challenge',
#  'big',
#  'data',
#  'analytics',
#  'review',
#  'data',
#  'mining',
#  'model',
#  'small',
#  'medium',
#  'enterprise',
#  'transportation',
#  'sector',
#  'big',
#  'data',
#  'analytics',
#  'apache',
#  'spark',
#  'applying',
#  'big',
#  'data',
#  'analytics',
#  'support',
#  'kansei',
#  'engineering',
#  'hotel',
#  'service',
#  'development',
#  'big',
#  'data',
#  'analytics',
#  'swarm',
#  'intelligence',
#  'entity',
#  'deduplication',
#  'big',
#  'data',
#  'graph',
#  'scholarly',
#  'communication',
#  'special',
#  'issue',
#  'first',
#  'international',
#  'conference',
#  'big',
#  'data',
#  'smart',
#  'computing',
#  'bigcomp',
#  'big',
#  'data',
#  'fusion',
#  'big',
#  'data',
#  'cloud',
#  'computing',
#  'insight',
#  'computing',
#  'environment',
#  'mapreduce',
#  'programming',
#  'framework',
#  'big',
#  'data',
#  'big',
#  'result',
#  'knowledge',
#  'discovery',
#  'output',
#  'large',
#  'scale',
#  'analytics',
#  'data',
#  'mining',
#  'big',
#  'data',
#  'data',
#  'analysis',
#  'big',
#  'data',
#  'improving',
#  'map',
#  'shuffle',
#  'phase',
#  'hadoop',
#  'map',
#  'reduce',
#  'analysis',
#  'academic',
#  'librarian',
#  'competency',
#  'skill',
#  'implementation',
#  'big',
#  'data',
#  'analytics',
#  'library',
#  'big',
#  'data',
#  'always',
#  'yield',
#  'big',
#  'benefit',
#  'big',
#  'data',
#  'improves',
#  'care',
#  'big',
#  'data',
#  'analytics',
#  'enabled',
#  'cyber',
#  'physical',
#  'system',
#  'model',
#  'application',
#  'big',
#  'bigger',
#  'biggest',
#  'data',
#  'repository',
#  'balloon',
#  'unprecedented',
#  'level',
#  'coping',
#  'big',
#  'data',
#  'big',
#  'data',
#  'internet',
#  'thing',
#  'revised',
#  'knowledge',
#  'pyramid',
#  'handling',
#  'big',
#  'dimension',
#  'distrubted',
#  'data',
#  'warehouse',
#  'using',
#  'dws',
#  'technique',
#  'quality',
#  'assessment',
#  'peer',
#  'produced',
#  'content',
#  'knowledge',
#  'repository',
#  'using',
#  'big',
#  'data',
#  'social',
#  'network',
#  'case',
#  'implicit',
#  'collaboration',
#  'wikipedia',
#  'big',
#  'data',
#  'analytics',
#  'machine',
#  'learning',
#  'bayesian',
#  'learning',
#  'perspective',
#  'done',
#  'big',
#  'data',
#  'paradigm',
#  'status',
#  'privacy',
#  'security',
#  'big',
#  'data',
#  'technology',
#  'process',
#  'spatial',
#  'attribute',
#  'data',
#  'designing',
#  'operating',
#  'mine',
#  'engineering',
#  'system',
#  'towards',
#  'big',
#  'linked',
#  'data',
#  'large',
#  'scale',
#  'distributed',
#  'semantic',
#  'data',
#  'storage',
#  'memory',
#  'big',
#  'data',
#  'management',
#  'processing',
#  'survey',
#  'spatial',
#  'data',
#  'mining',
#  'perspective',
#  'big',
#  'data',
#  'big',
#  'data',
#  'big',
#  'analysis',
#  'perspective',
#  'geographical',
#  'condition',
#  'monitoring',
#  'practical',
#  'big',
#  'data',
#  'exploring',
#  'big',
#  'data',
#  'analysis',
#  'fundamental',
#  'scientific',
#  'problem',
#  'managing',
#  'big',
#  'data',
#  'coal',
#  'fired',
#  'power',
#  'plant',
#  'business',
#  'intelligence',
#  'framework',
#  'analytics',
#  'partner',
#  'allina',
#  'health',
#  'team',
#  'health',
#  'catalyst',
#  'garner',
#  'benefit',
#  'big',
#  'data',
#  'using',
#  'data',
#  'build',
#  'better',
#  'em',
#  'em',
#  'big',
#  'data',
#  'tensor',
#  'based',
#  'big',
#  'data',
#  'management',
#  'scheme',
#  'dimensionality',
#  'reduction',
#  'problem',
#  'smart',
#  'grid',
#  'system',
#  'sdn',
#  'perspective',
#  'michael',
#  'buck',
#  'talk',
#  'living',
#  'dream',
#  'bioinformaticist',
#  'emerging',
#  'alternative',
#  'big',
#  'data',
#  'warehouse',
#  'eu',
#  'data',
#  'privacy',
#  'law',
#  'face',
#  'big',
#  'shake',
#  'scalable',
#  'multi',
#  'data',
#  'source',
#  'based',
#  'recursive',
#  'approximation',
#  'approach',
#  'fast',
#  'error',
#  'recovery',
#  'big',
#  'sensing',
#  'data',
#  'cloud',
#  'flexible',
#  'heavy',
#  'tailed',
#  'distribution',
#  'big',
#  'data',
#  'semantics',
#  'meet',
#  'big',
#  'data',
#  'formal',
#  'model',
#  'practical',
#  'issue',
#  'novel',
#  'paradigm',
#  'forecasting',
#  'big',
#  'data',
#  'review',
#  'china',
#  'deal',
#  'big',
#  'data',
#  'detailed',
#  'review',
#  'prominent',
#  'compression',
#  'method',
#  'used',
#  'reducing',
#  'data',
#  'volume',
#  'big',
#  'data',
#  'mongodb',
#  'based',
#  'modular',
#  'ontology',
#  'building',
#  'big',
#  'data',
#  'integration',
#  'scalable',
#  'data',
#  'chunk',
#  'similarity',
#  'based',
#  'compression',
#  'approach',
#  'efficient',
#  'big',
#  'sensing',
#  'data',
#  'processing',
#  'cloud',
#  'fuzzy',
#  'rule',
#  'based',
#  'classification',
#  'system',
#  'big',
#  'data',
#  'mapreduce',
#  'granularity',
#  'analysis',
#  'cell',
#  'phone',
#  'big',
#  'data',
#  'compute',
#  'mobility',
#  'scenario',
#  'future',
#  'smart',
#  'city',
#  'semantics',
#  'aware',
#  'approach',
#  'big',
#  'data',
#  'engineering',
#  'smart',
#  'city',
#  'big',
#  'data',
#  'analytics',
#  'advanced',
#  'review',
#  'watchdog',
#  'approach',
#  'name',
#  'matching',
#  'algorithm',
#  'big',
#  'data',
#  'risk',
#  'intelligence',
#  'intelligent',
#  'approach',
#  'big',
#  'data',
#  'analytics',
#  'sustainable',
#  'retail',
#  'environment',
#  'using',
#  'apriori',
#  'mapreduce',
#  'framework',
#  'organisation',
#  'leverage',
#  'big',
#  'data',
#  'maturity',
#  'model',
#  'effective',
#  'efficient',
#  'distributed',
#  'management',
#  'big',
#  'clinical',
#  'data',
#  'framework',
#  'simd',
#  'parallel',
#  'mcmc',
#  'sampling',
#  'application',
#  'big',
#  'data',
#  'bayesian',
#  'analytics',
#  'framework',
#  'evaluating',
#  'design',
#  'methodology',
#  'big',
#  'data',
#  'warehouse',
#  'measurement',
#  'design',
#  'process',
#  'stakeholder',
#  'perception',
#  'word',
#  'mouth',
#  'csr',
#  'dynamic',
#  'big',
#  'data',
#  'analysis',
#  'twitter',
#  'efficient',
#  'skyline',
#  'computation',
#  'big',
#  'data',
#  'incremental',
#  'query',
#  'processing',
#  'big',
#  'data',
#  'stream',
#  'barrier',
#  'embedding',
#  'big',
#  'data',
#  'solution',
#  'smart',
#  'factory',
#  'insight',
#  'sap',
#  'consultant',
#  'extracting',
#  'kernel',
#  'dataset',
#  'big',
#  'sensory',
#  'data',
#  'wireless',
#  'sensor',
#  'network',
#  'insight',
#  'application',
#  'big',
#  'data',
#  'analytics',
#  'healthcare',
#  'quantile',
#  'regression',
#  'big',
#  'data',
#  'divide',
#  'conquer',
#  'based',
#  'strategy',
#  'review',
#  'sentiment',
#  'discovery',
#  'analysis',
#  'educational',
#  'big',
#  'data',
#  'mr',
#  'plot',
#  'big',
#  'data',
#  'tool',
#  'distinguishing',
#  'distribution',
#  'overview',
#  'online',
#  'based',
#  'platform',
#  'sharing',
#  'analyzing',
#  'electrophysiology',
#  'data',
#  'big',
#  'data',
#  'perspective',
#  'holistic',
#  'view',
#  'big',
#  'data',
#  'modeling',
#  'evaluating',
#  'effect',
#  'big',
#  'data',
#  'storage',
#  'resource',
#  'allocation',
#  'global',
#  'scale',
#  'cloud',
#  'architecture',
#  'scalable',
#  'machine',
#  'learning',
#  'algorithm',
#  'big',
#  'data',
#  'analytics',
#  'comprehensive',
#  'review',
#  'advancing',
#  'science',
#  'technology',
#  'big',
#  'data',
#  'analytics',
#  'mapreduce',
#  'incremental',
#  'mapreduce',
#  'mining',
#  'evolving',
#  'big',
#  'data',
#  'multi',
#  'step',
#  'nonlinear',
#  'dimension',
#  'reduction',
#  'approach',
#  'application',
#  'big',
#  'data',
#  'efficient',
#  'distributed',
#  'generalized',
#  'canonical',
#  'correlation',
#  'analysis',
#  'big',
#  'multiview',
#  'data',
#  'web',
#  'medium',
#  'stock',
#  'market',
#  'survey',
#  ...]

# %% [markdown]
# # 2. 데이터 탐색

# %% [markdown]
# ## 2-1. 단어 빈도 탐색

# %%
count = Counter(words2)

count   #출력하여 내용 확인
# Out:
# Counter({'guest': 12,
#          'editorial': 17,
#          'big': 1354,
#          'medium': 11,
#          'data': 1645,
#          'understanding': 11,
#          'search': 7,
#          'mining': 40,
#          'part': 1,
#          'scholar': 3,
#          'discovery': 13,
#          'collaboration': 5,
#          'analytics': 137,
#          'web': 9,
#          'parallel': 5,
#          'computing': 25,
#          'preserving': 2,
#          'privacy': 17,
#          'using': 57,
#          'k': 7,
#          'anonymisation': 1,
#          'algorithm': 17,
#          'nosql': 4,
#          'database': 11,
#          'computation': 2,
#          'migration': 4,
#          'new': 38,
#          'approach': 44,
#          'execute': 1,
#          'bioinformatics': 2,
#          'workflow': 3,
#          'towards': 12,
#          'real': 14,
#          'time': 17,
#          'platform': 19,
#          'health': 37,
#          'application': 25,
#          'accurate': 3,
#          'distributed': 18,
#          'cluster': 2,
#          'analysis': 67,
#          'competitive': 6,
#          'mean': 9,
#          'five': 4,
#          'layer': 1,
#          'architecture': 11,
#          'processing': 30,
#          'max': 1,
#          'min': 1,
#          'fair': 2,
#          'resource': 5,
#          'allocation': 3,
#          'stream': 8,
#          'shared': 2,
#          'cloud': 34,
#          'large': 18,
#          'scale': 12,
#          'spectral': 2,
#          'clustering': 7,
#          'managing': 4,
#          'healthcare': 21,
#          'operation': 6,
#          'hierarchical': 1,
#          'framework': 26,
#          'image': 4,
#          'storage': 21,
#          'system': 50,
#          'online': 7,
#          'similarity': 2,
#          'learning': 33,
#          'overfitting': 1,
#          'quality': 23,
#          'service': 21,
#          'driven': 24,
#          'consistency': 2,
#          'management': 48,
#          'current': 5,
#          'trend': 6,
#          'predictive': 14,
#          'classification': 8,
#          'comparison': 1,
#          'model': 37,
#          'survey': 19,
#          'infrastructure': 12,
#          'evolving': 3,
#          'role': 10,
#          'fpga': 1,
#          'fast': 5,
#          'semantic': 7,
#          'composition': 1,
#          'environment': 18,
#          'secure': 2,
#          'multi': 11,
#          'owner': 1,
#          'based': 62,
#          'scheme': 3,
#          'corporate': 2,
#          'governance': 4,
#          'fraud': 6,
#          'detection': 6,
#          'annual': 1,
#          'report': 7,
#          'fuzzy': 2,
#          'scalable': 13,
#          'handling': 5,
#          'apache': 2,
#          'spark': 3,
#          'palopro': 1,
#          'knowledge': 22,
#          'extraction': 4,
#          'social': 24,
#          'news': 2,
#          'index': 4,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'hybridisation': 1,
#          'classifier': 1,
#          'anomaly': 2,
#          'toward': 7,
#          'efficient': 22,
#          'flexible': 2,
#          'metadata': 6,
#          'indexing': 4,
#          'structural': 3,
#          'balance': 1,
#          'theory': 9,
#          'e': 7,
#          'commerce': 2,
#          'recommendation': 2,
#          'rating': 1,
#          'petuum': 1,
#          'machine': 15,
#          'special': 12,
#          'issue': 24,
#          'biomedical': 3,
#          'smart': 34,
#          'monitoring': 7,
#          'camera': 3,
#          'intelligent': 7,
#          'surveillance': 2,
#          'video': 2,
#          'feature': 2,
#          'selection': 3,
#          'economic': 3,
#          'extended': 3,
#          'spatio': 1,
#          'temporal': 6,
#          'granger': 1,
#          'causality': 2,
#          'air': 3,
#          'estimation': 1,
#          'heterogeneous': 7,
#          'urban': 13,
#          'hdm': 1,
#          'composable': 1,
#          'enhanced': 2,
#          'visualization': 6,
#          'method': 18,
#          'aid': 1,
#          'behavioral': 4,
#          'trajectory': 3,
#          'pattern': 3,
#          'recognition': 1,
#          'longitudinal': 3,
#          'dip': 1,
#          'svm': 1,
#          'distribution': 7,
#          'kernel': 3,
#          'support': 9,
#          'vector': 2,
#          'availability': 1,
#          'modelling': 3,
#          'assurance': 3,
#          'deduplication': 2,
#          'encrypted': 2,
#          'continued': 1,
#          'kvasir': 1,
#          'provision': 1,
#          'semantically': 2,
#          'relevant': 2,
#          'content': 3,
#          'perception': 2,
#          'independent': 3,
#          'financial': 7,
#          'advisor': 1,
#          'usefulness': 1,
#          'context': 7,
#          'decision': 18,
#          'making': 19,
#          'uk': 2,
#          'optimized': 2,
#          'deep': 5,
#          'eeg': 1,
#          'seizure': 2,
#          'prediction': 13,
#          'bci': 1,
#          'via': 2,
#          'internet': 10,
#          'thing': 11,
#          'algorithmseer': 1,
#          'extracting': 3,
#          'searching': 1,
#          'scholarly': 4,
#          'taxi': 1,
#          'passenger': 1,
#          'demand': 6,
#          'modeling': 11,
#          'roving': 1,
#          'sensor': 7,
#          'network': 23,
#          'security': 12,
#          'criminal': 1,
#          'investigation': 3,
#          'discretization': 1,
#          'taxonomy': 2,
#          'challenge': 47,
#          'review': 22,
#          'small': 27,
#          'enterprise': 5,
#          'transportation': 3,
#          'sector': 8,
#          'applying': 6,
#          'kansei': 1,
#          'engineering': 5,
#          'hotel': 2,
#          'development': 8,
#          'swarm': 1,
#          'intelligence': 9,
#          'entity': 1,
#          'graph': 10,
#          'communication': 4,
#          'first': 5,
#          'international': 7,
#          'conference': 5,
#          'bigcomp': 1,
#          'fusion': 3,
#          'insight': 15,
#          'mapreduce': 7,
#          'programming': 2,
#          'result': 5,
#          'output': 1,
#          'improving': 4,
#          'map': 4,
#          'shuffle': 1,
#          'phase': 3,
#          'hadoop': 7,
#          'reduce': 1,
#          'academic': 3,
#          'librarian': 8,
#          'competency': 1,
#          'skill': 3,
#          'implementation': 1,
#          'library': 1,
#          'always': 3,
#          'yield': 2,
#          'benefit': 8,
#          'improves': 1,
#          'care': 17,
#          'enabled': 6,
#          'cyber': 1,
#          'physical': 3,
#          'bigger': 7,
#          'biggest': 6,
#          'repository': 5,
#          'balloon': 1,
#          'unprecedented': 1,
#          'level': 3,
#          'coping': 2,
#          'revised': 1,
#          'pyramid': 1,
#          'dimension': 4,
#          'distrubted': 1,
#          'warehouse': 14,
#          'dws': 2,
#          'technique': 7,
#          'assessment': 5,
#          'peer': 1,
#          'produced': 1,
#          'case': 13,
#          'implicit': 2,
#          'wikipedia': 1,
#          'bayesian': 4,
#          'perspective': 21,
#          'done': 3,
#          'paradigm': 2,
#          'status': 1,
#          'technology': 28,
#          'process': 19,
#          'spatial': 10,
#          'attribute': 1,
#          'designing': 3,
#          'operating': 2,
#          'mine': 2,
#          'linked': 6,
#          'memory': 5,
#          'geographical': 1,
#          'condition': 4,
#          'practical': 6,
#          'exploring': 5,
#          'fundamental': 1,
#          'scientific': 6,
#          'problem': 13,
#          'coal': 1,
#          'fired': 1,
#          'power': 4,
#          'plant': 4,
#          'business': 18,
#          'partner': 1,
#          'allina': 1,
#          'team': 5,
#          'catalyst': 2,
#          'garner': 1,
#          'build': 2,
#          'better': 3,
#          'em': 3,
#          'tensor': 2,
#          'dimensionality': 1,
#          'reduction': 2,
#          'grid': 3,
#          'sdn': 3,
#          'michael': 3,
#          'buck': 3,
#          'talk': 1,
#          'living': 1,
#          'dream': 2,
#          'bioinformaticist': 1,
#          'emerging': 7,
#          'alternative': 3,
#          'eu': 5,
#          'law': 14,
#          'face': 3,
#          'shake': 2,
#          'source': 9,
#          'recursive': 1,
#          'approximation': 1,
#          'error': 2,
#          'recovery': 2,
#          'sensing': 7,
#          'heavy': 1,
#          'tailed': 1,
#          'semantics': 5,
#          'meet': 12,
#          'formal': 1,
#          'novel': 4,
#          'forecasting': 5,
#          'china': 5,
#          'deal': 23,
#          'detailed': 2,
#          'prominent': 1,
#          'compression': 2,
#          'used': 3,
#          'reducing': 1,
#          'volume': 6,
#          'mongodb': 1,
#          'modular': 1,
#          'ontology': 4,
#          'building': 8,
#          'integration': 5,
#          'chunk': 1,
#          'rule': 2,
#          'granularity': 1,
#          'cell': 1,
#          'phone': 1,
#          'compute': 2,
#          'mobility': 2,
#          'scenario': 2,
#          'future': 13,
#          'city': 17,
#          'aware': 9,
#          'advanced': 5,
#          'watchdog': 1,
#          'name': 1,
#          'matching': 1,
#          'risk': 12,
#          'sustainable': 4,
#          'retail': 2,
#          'apriori': 1,
#          'organisation': 1,
#          'leverage': 4,
#          'maturity': 2,
#          'effective': 7,
#          'clinical': 10,
#          'simd': 1,
#          'mcmc': 1,
#          'sampling': 3,
#          'evaluating': 2,
#          'design': 14,
#          'methodology': 3,
#          'measurement': 6,
#          'stakeholder': 2,
#          'word': 2,
#          'mouth': 1,
#          'csr': 1,
#          'dynamic': 7,
#          'twitter': 4,
#          'skyline': 1,
#          'incremental': 3,
#          'query': 6,
#          'barrier': 2,
#          'embedding': 1,
#          'solution': 13,
#          'factory': 5,
#          'sap': 1,
#          'consultant': 1,
#          'dataset': 1,
#          'sensory': 1,
#          'wireless': 4,
#          'quantile': 1,
#          'regression': 2,
#          'divide': 4,
#          'conquer': 3,
#          'strategy': 12,
#          'sentiment': 6,
#          'educational': 1,
#          'mr': 1,
#          'plot': 1,
#          'tool': 12,
#          'distinguishing': 1,
#          'overview': 4,
#          'sharing': 14,
#          'analyzing': 7,
#          'electrophysiology': 1,
#          'holistic': 1,
#          'view': 4,
#          'effect': 3,
#          'global': 5,
#          'comprehensive': 4,
#          'advancing': 2,
#          'science': 50,
#          'step': 2,
#          'nonlinear': 1,
#          'generalized': 2,
#          'canonical': 1,
#          'correlation': 2,
#          'multiview': 1,
#          'stock': 2,
#          'market': 18,
#          'direction': 2,
#          'nearest': 3,
#          'neighbour': 1,
#          'join': 4,
#          'theoretical': 2,
#          'experimental': 2,
#          'haery': 1,
#          'accumulative': 1,
#          'high': 7,
#          'dimensional': 2,
#          'va': 1,
#          'store': 3,
#          'virtual': 3,
#          'approximate': 2,
#          'supporting': 3,
#          'repetitive': 1,
#          'genome': 1,
#          'sequence': 2,
#          'feasibility': 1,
#          'neighbor': 2,
#          'gamma': 1,
#          'matrix': 1,
#          'summarize': 1,
#          'dense': 1,
#          'sparse': 4,
#          'set': 10,
#          'uncertainty': 3,
#          'measure': 4,
#          'conflict': 1,
#          'evidence': 6,
#          'dempster': 1,
#          'shafer': 1,
#          'pcce': 1,
#          'personality': 1,
#          'communicative': 1,
#          'community': 3,
#          'suspicious': 1,
#          'tax': 1,
#          'evasion': 1,
#          'group': 2,
#          'bias': 3,
#          'correction': 3,
#          'sample': 4,
#          'pipeline': 3,
#          'broadcasting': 1,
#          'transforming': 4,
#          'v': 3,
#          'non': 2,
#          'simple': 2,
#          'pre': 4,
#          'government': 8,
#          'legal': 7,
#          'question': 16,
#          'stay': 3,
#          'ip': 1,
#          'todd': 1,
#          'vare': 1,
#          'mattioli': 1,
#          'look': 4,
#          'protected': 1,
#          'u': 12,
#          'ask': 1,
#          'whether': 3,
#          'thrive': 1,
#          'existing': 1,
#          'creating': 7,
#          'example': 4,
#          'use': 22,
#          'consequence': 6,
#          'concept': 3,
#          'hard': 3,
#          'quantify': 1,
#          'good': 7,
#          'remember': 1,
#          'hat': 1,
#          'made': 2,
#          'amp': 7,
#          'p': 5,
#          'industry': 11,
#          'must': 4,
#          'work': 7,
#          'growing': 3,
#          'population': 3,
#          'addressing': 2,
#          'personalized': 2,
#          'bang': 4,
#          'iron': 1,
#          'fifteen': 1,
#          'year': 3,
#          'cosmic': 1,
#          'microwave': 1,
#          'background': 1,
#          'nersc': 1,
#          'impact': 10,
#          'four': 4,
#          'computerworld': 1,
#          'honor': 1,
#          'laureate': 1,
#          'battle': 1,
#          'unemployment': 1,
#          'climate': 3,
#          'change': 9,
#          'raise': 2,
#          'awareness': 1,
#          'help': 8,
#          'student': 5,
#          'gain': 7,
#          'pain': 4,
#          'lawyer': 3,
#          'huge': 3,
#          'quantity': 3,
#          'offer': 6,
#          'potential': 14,
#          'boon': 1,
#          'cause': 2,
#          'headache': 3,
#          'money': 8,
#          'make': 10,
#          'major': 2,
#          'difference': 1,
#          'even': 1,
#          'value': 15,
#          'spinning': 1,
#          'provides': 6,
#          'lesson': 1,
#          'prevent': 2,
#          'becoming': 6,
#          'job': 3,
#          'company': 15,
#          'embrace': 1,
#          'strategist': 1,
#          'communicator': 1,
#          'chop': 1,
#          'snag': 1,
#          'energy': 10,
#          'link': 1,
#          'innovation': 9,
#          'old': 1,
#          'school': 2,
#          'sears': 1,
#          'trying': 1,
#          'km': 1,
#          'competition': 1,
#          'think': 2,
#          'identifying': 2,
#          'suitable': 1,
#          'cognitive': 1,
#          'research': 38,
#          'implication': 6,
#          'really': 7,
#          'digital': 10,
#          'administrative': 2,
#          'compared': 1,
#          'updating': 1,
#          'classical': 1,
#          'toolbox': 1,
#          'assessing': 3,
#          'exemplified': 1,
#          'generation': 7,
#          'corruption': 1,
#          'software': 8,
#          'defined': 3,
#          'networking': 3,
#          'hope': 3,
#          'hype': 6,
#          'early': 3,
#          'conceptual': 2,
#          'snapshot': 1,
#          'latin': 2,
#          'america': 1,
#          'american': 1,
#          'country': 1,
#          'long': 4,
#          'way': 12,
#          'go': 1,
#          'develop': 2,
#          'regional': 1,
#          'politics': 3,
#          'brother': 7,
#          'finding': 6,
#          'space': 6,
#          'peril': 1,
#          'r': 3,
#          'tnani': 1,
#          'schneidern': 1,
#          'green': 5,
#          'ed': 1,
#          'londonroutledge': 1,
#          'pp': 5,
#          'isbn': 4,
#          'york': 2,
#          'kalvi': 1,
#          'human': 10,
#          'project': 8,
#          'aim': 2,
#          'resolving': 1,
#          'listen': 1,
#          'cmos': 1,
#          'turned': 1,
#          'action': 4,
#          'present': 3,
#          'unlimited': 1,
#          'opportunity': 31,
#          'marketer': 6,
#          'know': 6,
#          'interpreting': 1,
#          'auctioning': 1,
#          'correctly': 1,
#          'brand': 3,
#          'see': 3,
#          'consumer': 7,
#          'coming': 4,
#          'back': 1,
#          'implementing': 3,
#          'introduction': 10,
#          'center': 12,
#          'plateau': 1,
#          'island': 1,
#          'tech': 4,
#          'protecting': 2,
#          'patient': 11,
#          'diverse': 1,
#          'benchmark': 2,
#          'reveal': 1,
#          'optimization': 8,
#          'imperative': 1,
#          'membrane': 1,
#          'function': 2,
#          'promise': 13,
#          'pay': 2,
#          'dividend': 1,
#          'swd': 2,
#          'inc': 1,
#          'continuous': 1,
#          'improvement': 2,
#          'minded': 1,
#          'provider': 2,
#          'metal': 1,
#          'finishing': 1,
#          'fastener': 1,
#          'sorting': 1,
#          'allows': 1,
#          'unlock': 2,
#          'pathway': 3,
#          'improved': 5,
#          'performance': 10,
#          'serf': 1,
#          'foundation': 3,
#          'customer': 5,
#          'revolution': 8,
#          'continues': 1,
#          'unleash': 2,
#          'ever': 1,
#          'upon': 1,
#          'world': 16,
#          'cii': 1,
#          'ordnance': 1,
#          'information': 26,
#          'harnessed': 1,
#          'like': 2,
#          'mayo': 1,
#          'clinic': 2,
#          'intermountain': 1,
#          'turning': 4,
#          'outside': 1,
#          'firm': 3,
#          'boost': 4,
#          'analytical': 3,
#          'capability': 3,
#          'centre': 6,
#          'next': 12,
#          'statistician': 1,
#          'pharma': 1,
#          'transform': 2,
#          'supply': 7,
#          'chain': 9,
#          'reform': 2,
#          'european': 4,
#          'protection': 13,
#          'concern': 4,
#          'associated': 1,
#          'proposal': 1,
#          'personal': 5,
#          'idea': 3,
#          'president': 2,
#          'message': 3,
#          'unintended': 1,
#          'manufacturing': 6,
#          'recent': 4,
#          'advance': 5,
#          'era': 22,
#          'open': 20,
#          'fan': 1,
#          'among': 4,
#          'giant': 2,
#          'low': 2,
#          'cost': 5,
#          'scalability': 1,
#          'flexibility': 1,
#          'headed': 1,
#          'wider': 1,
#          'adaptive': 1,
#          'flow': 7,
#          'utility': 3,
#          'seek': 1,
#          'extract': 3,
#          'asset': 4,
#          'metering': 2,
#          'gold': 3,
#          'improve': 9,
#          'save': 3,
#          'little': 12,
#          'scholarship': 6,
#          'networked': 5,
#          'christine': 2,
#          'l': 5,
#          'borgman': 2,
#          'intensive': 5,
#          'unit': 2,
#          'closing': 1,
#          'loop': 1,
#          'crunch': 3,
#          'access': 3,
#          'modern': 3,
#          'biology': 6,
#          'study': 11,
#          'daze': 1,
#          'surrounded': 1,
#          'substance': 2,
#          'behind': 3,
#          'progress': 2,
#          'public': 11,
#          'private': 2,
#          'forum': 2,
#          'economics': 1,
#          'outcome': 5,
#          'collection': 8,
#          'begets': 1,
#          'handprint': 1,
#          'remote': 7,
#          'vehicle': 2,
#          'diagnostic': 1,
#          'usage': 2,
#          'experience': 5,
#          'acquisition': 3,
#          'intention': 1,
#          'best': 9,
#          'jay': 2,
#          'inamdar': 2,
#          'explains': 3,
#          'stat': 1,
#          'university': 2,
#          'pittsburgh': 1,
#          'medical': 6,
#          'invests': 1,
#          'million': 1,
#          'common': 2,
#          'pitfall': 6,
#          'transcriptomics': 1,
#          'representation': 6,
#          'universe': 1,
#          'astronomy': 2,
#          'expert': 6,
#          'interview': 2,
#          'bipin': 1,
#          'chadha': 1,
#          'scientist': 9,
#          'united': 3,
#          'automobile': 1,
#          'association': 1,
#          'usaa': 1,
#          'flood': 1,
#          'navy': 1,
#          'want': 4,
#          'embracing': 1,
#          'movement': 3,
#          'could': 1,
#          'revolutionize': 1,
#          'daddy': 1,
#          'ge': 1,
#          'stake': 1,
#          'claim': 2,
#          'industrial': 4,
#          'would': 2,
#          'efficiency': 4,
#          'since': 1,
#          'broadcast': 2,
#          'gemma': 1,
#          'carver': 1,
#          'marketing': 5,
#          'director': 1,
#          'restaurant': 1,
#          'reservation': 1,
#          'livebookings': 1,
#          'reveals': 2,
#          'importance': 1,
#          'mobile': 8,
#          'plan': 4,
#          'increase': 1,
#          'personalisation': 1,
#          'dealing': 1,
#          'eco': 1,
#          'fight': 1,
#          'vie': 1,
#          'analyse': 1,
#          'series': 3,
#          'katharine': 1,
#          'bagshaw': 1,
#          'fca': 1,
#          'examines': 2,
#          'scope': 2,
#          'audit': 3,
#          'ci': 1,
#          'creates': 1,
#          'veterinary': 1,
#          'datasets': 5,
#          'dilemma': 2,
#          'threat': 1,
#          'finance': 1,
#          'metaphor': 1,
#          'collective': 1,
#          'wisdom': 1,
#          'local': 2,
#          'leveraging': 7,
#          'subscriber': 1,
#          'regulation': 3,
#          'regulatory': 3,
#          'compliance': 2,
#          'optic': 2,
#          'create': 3,
#          'responsive': 1,
#          'driving': 1,
#          'manage': 1,
#          'drown': 1,
#          'exponential': 1,
#          'growth': 1,
#          'challenging': 1,
#          'ability': 2,
#          'effectively': 1,
#          'exploit': 2,
#          'contains': 1,
#          'discussion': 4,
#          'construction': 1,
#          'borther': 1,
#          'equifax': 1,
#          'product': 6,
#          'billion': 1,
#          'record': 3,
#          'worldwide': 2,
#          'cio': 1,
#          'edge': 2,
#          'precision': 3,
#          'agriculture': 2,
#          'rise': 2,
#          'agricultural': 1,
#          'heart': 1,
#          'informatics': 3,
#          'cardiovascular': 3,
#          'imaging': 5,
#          'eo': 1,
#          'material': 3,
#          'training': 4,
#          'capitalizing': 1,
#          'require': 1,
#          'trained': 1,
#          'several': 1,
#          'answering': 2,
#          'call': 9,
#          'drug': 3,
#          'safety': 4,
#          'discus': 5,
#          'treatment': 7,
#          'quantitative': 1,
#          'scientometrics': 1,
#          'interpolation': 1,
#          'aggregation': 2,
#          'abstract': 2,
#          'midata': 1,
#          'book': 3,
#          'reading': 1,
#          'literary': 1,
#          'history': 1,
#          'preliminary': 4,
#          'easier': 1,
#          'marktforschung': 1,
#          'den': 1,
#          'zeiten': 1,
#          'von': 1,
#          'ensure': 2,
#          'confidence': 1,
#          'arrival': 1,
#          'friend': 1,
#          'foe': 1,
#          'advertising': 1,
#          'advantage': 4,
#          'need': 15,
#          'planning': 7,
#          'creativity': 1,
#          'mistake': 2,
#          'societas': 1,
#          'europaea': 1,
#          'herpetologica': 1,
#          'atlas': 1,
#          'sillero': 1,
#          'et': 1,
#          'al': 1,
#          'emys': 1,
#          'orbicularis': 1,
#          'misunderstood': 1,
#          'washington': 1,
#          'state': 10,
#          'cannabis': 1,
#          'limitation': 2,
#          'life': 6,
#          'locality': 1,
#          'evaluation': 5,
#          'researcher': 2,
#          'begin': 2,
#          'massive': 4,
#          'chaos': 2,
#          'multiply': 1,
#          'individual': 6,
#          'considering': 2,
#          'side': 1,
#          'brings': 1,
#          'home': 1,
#          'bacon': 1,
#          'invested': 1,
#          'creation': 4,
#          'derive': 2,
#          'genetic': 1,
#          'posed': 1,
#          'medicinal': 1,
#          'chemistry': 3,
#          'block': 1,
#          'fall': 1,
#          'place': 2,
#          'takeaway': 1,
#          'two': 3,
#          'hour': 1,
#          'event': 2,
#          'ucsd': 1,
#          'campus': 1,
#          'called': 2,
#          'conversation': 1,
#          'suggestion': 1,
#          'consideration': 3,
#          'analytic': 3,
#          'puerto': 1,
#          'rico': 1,
#          'third': 2,
#          'final': 1,
#          'article': 4,
#          'jonathan': 3,
#          'kettleborough': 3,
#          'highlight': 2,
#          'number': 4,
#          'england': 1,
#          'barn': 1,
#          'ambient': 1,
#          'tacit': 1,
#          'epistemology': 1,
#          ...})

# %%
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1645
# big : 1354
# analytics : 137
# analysis : 67
# based : 62
# using : 57
# system : 50
# science : 50
# management : 48
# challenge : 47
# approach : 44
# mining : 40
# new : 38
# research : 38
# health : 37
# model : 37
# cloud : 34
# smart : 34
# learning : 33
# opportunity : 31
# processing : 30
# technology : 28
# small : 27
# framework : 26
# information : 26
# computing : 25
# application : 25
# driven : 24
# social : 24
# issue : 24
# quality : 23
# network : 23
# deal : 23
# knowledge : 22
# efficient : 22
# review : 22
# use : 22
# era : 22
# healthcare : 21
# storage : 21
# service : 21
# perspective : 21
# open : 20
# platform : 19
# survey : 19
# making : 19
# process : 19
# distributed : 18
# large : 18
# environment : 18

# %% [markdown]
# #### 검색어로 사용한 big'과 'data' 빈도가 압도적으로 많으므로, 이를 제거한다.

# %%
#검색어로 사용한 'big'과 'data' 항목 제거 하기
del word_count['big']
del word_count['data']

# %% [markdown]
# ## 2-2 단어 빈도 히스토그램

# %%
# 히스토그램 표시 옵션 
plt.figure(figsize=(12,5))
plt.xlabel("word")
plt.ylabel("count")
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='85')

plt.show()

# %% [markdown]
# # 3. 분석 모델 구축 및 결과 시각화

# %% [markdown]
# ## 3-1. 연도별 데이터 수

# %%
all_files_data_concat['doc_count'] = 0
summary_year = all_files_data_concat.groupby('출판일', as_index=False)['doc_count'].count()
summary_year  #출력하여 내용 확인
# Out:
#      출판일  doc_count
# 0   1994          1
# 1   1995          1
# 2   1996          1
# 3   1998          3
# 4   2002          4
# 5   2003          1
# 6   2004          3
# 7   2005          3
# 8   2007          2
# 9   2008          3
# 10  2009          2
# 11  2010          3
# 12  2011          8
# 13  2012         34
# 14  2013         87
# 15  2014        154
# 16  2015        114
# 17  2016        139
# 18  2017        158
# 19  2018        130
# 20  2019        106
# 21  2020         43

# %%
plt.figure(figsize=(12,5))
plt.xlabel("year")
plt.ylabel("doc-count")
plt.grid(True)

plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt.xticks(range(len(summary_year)), [text for text in summary_year['출판일']])

plt.show()

# %% [markdown]
# ## 3-2. 워드클라우드

# %%
# 워드클라우드에서 처리할 불용어를 설정
# 워드클라우드 객체를 생성
# 워드클라우드 객체 wc에 word_count를 추가하여 cloud 객체를 생성

stopwords=set(STOPWORDS)
wc=WordCloud(background_color='ivory', stopwords=stopwords, width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# #### - 워드 클라우드에 나타나는 단어의 위치는 실행 할 때마다 달라질 수 있음

# %%
cloud.to_file("data/riss_bigdata_wordCloud.jpg")
